# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import re
import nltk
import pickle
import numpy as np
import pandas as pd
from math import log
import urllib.request
from tqdm import tqdm
from sklearn import svm
import matplotlib.pyplot as plt
from collections import Counter
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from sklearn.preprocessing import LabelEncoder
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.lancaster import LancasterStemmer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split 
from nltk.tokenize import word_tokenize, sent_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# amazon = pd.read_csv('/content/drive/My Drive/amazon_reviews.csv')
# binary_airline = pd.read_csv('/content/drive/My Drive/binary_air_review.csv')
# binary_hotel = pd.read_csv('/content/drive/My Drive/hotel-reviews.csv')
# clothing = pd.read_csv('/content/drive/My Drive/clothing.csv')
# movie = pd.read_csv('/content/drive/My Drive/train.csv')
# steam = pd.read_csv('/content/drive/My Drive/steam.csv')
yelp = pd.read_csv('/content/drive/My Drive/yelp.csv')

# %%
# sorting = amazon.sort_values(['label'])                     ## contents
# sorting = binary_airline.sort_values(['rating'])            ## comment
# sorting = binary_hotel.sort_values(['Is_Response'])         ## Description
# sorting = clothing.sort_values(['Recommended IND'])         ## Review Text
# sorting = movie.sort_values(['sentiment'])                  ## text
# sorting = steam.sort_values(['user_suggestion'])            ## user_review
sorting = yelp.sort_values(['rating'])                      ## review

# %%
sorting
# Out:
#        rating                                             review
# 18999       1  My husband was in the hospital for blood clots...
# 20704       1  DON'T GO!!! \nWorst experience ever!!! \nYou p...
# 20703       1  This is hard to review.  The reason being is t...
# 20701       1  I don't really get the whole \"sexy\" thing wi...
# 20700       1  I used to come here when I lived in student ha...
# ...       ...                                                ...
# 22104       2  Best local pizza! Just order the Cheeseburger ...
# 22103       2  Great food, mediocre service, very long wait t...
# 22102       2  I absolutely love this sushi place it's right ...
# 7652        2  Friends had gone on our last trip to LV and I ...
# 0           2  Contrary to other reviews, I have zero complai...
#
# [38000 rows x 2 columns]

# %%
## 본문부분 열 이름과 점수부분 열 이름 입력

contents_name = "review"
label_name = "rating"

# %%
def data_loading(sorting, contents_name, label_name):

  review_ = sorting.reset_index()
  # 라벨 인코더 생성
  encoder = LabelEncoder()

  # X_train데이터를 이용 피팅하고 라벨숫자로 변환한다
  encoder.fit(review_[label_name])
  target_encoded = encoder.transform(review_[label_name])

  contents = list(np.array(review_[contents_name].tolist()))
  label = list(target_encoded)
  cnts_N = contents[:2000]+contents[-2000:]   ## X_train
  label_N = label[:2000]+label[-2000:]        ## y_train

  ## train data를 제외한 test data
  test_dict = {'document':contents[2000:-2000],"label":label[2000:-2000]}
  test_df = pd.DataFrame(test_dict)

  np.random.seed(0)

  df_shuffled=test_df.iloc[np.random.permutation(test_df.index)].reset_index(drop=True)
  df_shuffled

  tdata = df_shuffled['document']
  tlabel = df_shuffled['label']

  return cnts_N, label_N, tdata, tlabel

# %%
## train test split과 같이 진행

train_X, train_Y, test_X, test_Y = data_loading(sorting, contents_name, label_name)

# %%
def preprocessing(data):

    from nltk import FreqDist
    from nltk.stem.snowball import SnowballStemmer
    snowball = SnowballStemmer('english')

    normalized_text = []  ## 괄호 제거 및 문자이외의 데이터 제거
    for scr in data:
        scr = re.sub('\(', ' ', scr)
        scr = re.sub('\)', ' ', scr)
        scr = re.sub('[^ a-zA-Zㄱ-힗]', '', scr)
        normalized_text.append(scr.lower())

    result = [word_tokenize(sentence) for sentence in normalized_text]  ## 토큰화

    ## 단어 빈도 수 계산( 10번이상 등장하지 않는 단어 stopword에 포함 )
    vocab = list(set(w for i in result for w in i))
    vocab.sort()

    check_freq = []
    for line in result:
        for wd in line:
            check_freq.append(wd)

    fdist = FreqDist(check_freq)

    low_freq = []
    for i in vocab:
        if fdist[i] < 10:
            low_freq.append(i)

    stop_words = set(stopwords.words('english'))
    stop_words = list(stop_words)
    for i in low_freq:
        stop_words.append(i)

    ## stopwords 제거 및 stemming
    except_stopword = []
    for st in result:
        temp = []
        for tk in st:
            if tk not in stop_words:
                temp.append(snowball.stem(tk))
        except_stopword.append(temp)
    
    return except_stopword

# %%
## train data 토큰화

train_tokens = preprocessing(train_X)

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in train_tokens))
print('리뷰의 평균 길이 :',sum(map(len, train_tokens))/len(train_tokens))
plt.hist([len(s) for s in train_tokens], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 381
# 리뷰의 평균 길이 : 56.27275

# %%
vocab = list(set(w for i in train_tokens for w in i ))
vocab.sort()

# %%
print('단어의 갯수는 총 %d개 이다'%(len(vocab)))
# Out:
# 단어의 갯수는 총 2451개 이다

# %%
## 전처리 된 단어들을 다시 문장화

def corpus(tokens):
  corp = []
  for sent in tokens:
    tmp = " ".join(sent)
    corp.append(tmp)

  return corp

train_corp = corpus(train_tokens)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
import operator

## Support Vector Classifier를 이용한 사전생성

def score_importance(corpus, label):

  from sklearn import svm
  vector = TfidfVectorizer()
  tfidf_matrix = vector.fit_transform(corpus).toarray()

  svm = svm.SVC(C=1.0, kernel='linear',degree = 1, probability=True)
  svm.fit(tfidf_matrix, label)
  importance = svm.coef_

  v_dict = vector.vocabulary_
  rv_dict = {}
  for k,v in v_dict.items():
    rv_dict[v] = k

  score_dict = {}
  for i,v in enumerate(importance[0]):
    score_dict[rv_dict[i]] = v

  score_dict = sorted(score_dict.items(), key=operator.itemgetter(1))
  
  return dict(score_dict)

score_dict = score_importance(train_corp, train_Y)

# %%
score_dict
# Out:
# {'worst': -3.1106226629179647,
#  'terribl': -2.9491912124357196,
#  'mediocr': -2.8267643185834808,
#  'ok': -2.590395058688986,
#  'bad': -2.4671391697152654,
#  'bland': -2.4155553109867305,
#  'disappoint': -2.378071388775733,
#  'poor': -2.329358412296626,
#  'noth': -2.321252273979762,
#  'expens': -2.1013003109173507,
#  'overpr': -2.055758394486449,
#  'horribl': -2.010919028575538,
#  'dri': -1.9805443280859518,
#  'disgust': -1.9206655362201541,
#  'aw': -1.8297887354798514,
#  'rude': -1.826998891859657,
#  'lack': -1.7902230555028706,
#  'pay': -1.7439090707376166,
#  'suck': -1.7199055278828879,
#  'mayb': -1.7083951811632676,
#  'unfortun': -1.701431498041344,
#  'almost': -1.6919812361230684,
#  'guess': -1.675065946234063,
#  'would': -1.6628195825712424,
#  'paid': -1.6178851875157583,
#  'wasnt': -1.6151201136232454,
#  'two': -1.59721222919896,
#  'said': -1.5957047922568794,
#  'wast': -1.5601982632934692,
#  'sorri': -1.555637947138485,
#  'unless': -1.5458642959716713,
#  'anymor': -1.5226248439638699,
#  'never': -1.5182417925029748,
#  'broken': -1.507648108771135,
#  'averag': -1.461747881281175,
#  'build': -1.4438256106804066,
#  'pub': -1.4266668505504219,
#  'slow': -1.4203558117095763,
#  'howev': -1.3987133270618393,
#  'what': -1.3985734497070723,
#  'better': -1.3978536300930724,
#  'stick': -1.3920885094887283,
#  'stuck': -1.392045988117797,
#  'told': -1.3860088623573323,
#  'order': -1.3727052351269338,
#  'liter': -1.3411872941723602,
#  'wouldnt': -1.3408152699770057,
#  'couldnt': -1.3321764085194614,
#  'rip': -1.3204325125231644,
#  'way': -1.309795274014333,
#  'vacat': -1.307347316686855,
#  'wont': -1.3053273769153997,
#  'bare': -1.2907306550504467,
#  'bore': -1.2732366260118528,
#  'nobodi': -1.2648456530069294,
#  'subpar': -1.2637904708904786,
#  'meh': -1.2579400526949065,
#  'creepi': -1.253677544725998,
#  'bother': -1.2436038950070114,
#  'plain': -1.2309043647097635,
#  'soggi': -1.229989949845578,
#  'tast': -1.227731805108633,
#  'cold': -1.2266935494510527,
#  'sad': -1.2203684311459684,
#  'left': -1.2004055647664997,
#  'dont': -1.1992365333268766,
#  'excit': -1.1958348341947986,
#  'avoid': -1.1950050679774682,
#  'can': -1.1939596004449622,
#  'male': -1.180625914104587,
#  'hungri': -1.1694757276967676,
#  'lost': -1.1619237929824782,
#  'gross': -1.1605829146142916,
#  'look': -1.1585948547044542,
#  'cost': -1.1501940480482746,
#  'okay': -1.1495997625345253,
#  'min': -1.147580225896905,
#  'book': -1.1468261006291496,
#  'cover': -1.1450754039671798,
#  'overdon': -1.1211275763776956,
#  'sick': -1.1113111834665843,
#  'dark': -1.110049568498498,
#  'elsewher': -1.1098952005271583,
#  'someth': -1.1088429370659303,
#  'tasteless': -1.1082369899800173,
#  'paper': -1.1048399710993042,
#  'seem': -1.1041028188525521,
#  'idea': -1.1034925064715897,
#  'weak': -1.09843230956232,
#  'unprofession': -1.0973194833749902,
#  'dirti': -1.085360219762702,
#  'think': -1.0839018167528807,
#  'ignor': -1.0770475962491446,
#  'tini': -1.0718796186445692,
#  'ask': -1.0668481378111496,
#  'appear': -1.0651444021818586,
#  'pad': -1.0577383870688122,
#  'premium': -1.0528738028787352,
#  'speak': -1.0522195141787123,
#  'floor': -1.0504441380812968,
#  'otherwis': -1.0474335241774035,
#  'overcook': -1.045538083742528,
#  'hope': -1.043604486878691,
#  'omelett': -1.0385941464833683,
#  'support': -1.0364758929993225,
#  'even': -1.0197498455264715,
#  'age': -1.0178517942795897,
#  'wrong': -1.003625581065692,
#  'mcdonald': -1.0034664930230952,
#  'manag': -1.0033207783685893,
#  'tough': -0.9889620346640973,
#  'charg': -0.985843303994278,
#  'ill': -0.9820272382139668,
#  'waitress': -0.9740851377287871,
#  'incorrect': -0.9693051027558577,
#  'tire': -0.9659122641208319,
#  'bs': -0.9652020625007443,
#  'posit': -0.9635546051542677,
#  'bewar': -0.9608689776879964,
#  'confus': -0.9591322053699008,
#  'hate': -0.9550897849864228,
#  'broke': -0.9547148150993423,
#  'rather': -0.9467330473660795,
#  'mistak': -0.9460990283112778,
#  'stale': -0.9322457991566213,
#  'blah': -0.92990321326497,
#  'cook': -0.9288720421869885,
#  'danger': -0.9245853230690831,
#  'minut': -0.9215373367571683,
#  'wash': -0.9196361119718814,
#  'pound': -0.9143753703121423,
#  'favor': -0.9134158374725092,
#  'brew': -0.9110875771137522,
#  'third': -0.9075141759080876,
#  'screw': -0.9064742579998701,
#  'espresso': -0.9041593057788472,
#  'theyv': -0.8980548420172952,
#  'obvious': -0.8945342176255313,
#  'break': -0.8906022236837592,
#  'ago': -0.887996548587174,
#  'thin': -0.8871485552985763,
#  'food': -0.8843116669688225,
#  'mess': -0.8826625944246782,
#  'languag': -0.8817254665659766,
#  'ridicul': -0.8791129267082916,
#  'men': -0.8740105565980383,
#  'horrend': -0.8731419974018149,
#  'knife': -0.8718079083327801,
#  'portion': -0.8640691694655319,
#  'experi': -0.8580100143967495,
#  'shame': -0.8578668410396145,
#  'lame': -0.855902380435789,
#  'send': -0.8556032743390757,
#  'hype': -0.8487118850661143,
#  'wors': -0.8475133500954435,
#  'read': -0.8368055320246022,
#  'fight': -0.8302178148897331,
#  'sigh': -0.8298495621846304,
#  'refil': -0.8293805273853454,
#  'respons': -0.8221498208801686,
#  'arriv': -0.8215628060347189,
#  'annoy': -0.8157963807940548,
#  'warn': -0.8117911929989068,
#  'serious': -0.8077835112126142,
#  'zero': -0.8038142337293566,
#  'second': -0.796946677799758,
#  'smell': -0.7953208069870337,
#  'wax': -0.7904233563894552,
#  'locat': -0.7887117227310583,
#  'front': -0.7886884303136942,
#  'trop': -0.7848837053451094,
#  'electr': -0.7847166247010944,
#  'receiv': -0.7831816658942583,
#  'decent': -0.7798957970919436,
#  'opinion': -0.7721728660386937,
#  'appar': -0.7718031891575886,
#  'main': -0.7709216169589981,
#  'meat': -0.7697346135151318,
#  'oil': -0.7677500368085192,
#  'given': -0.7638987908520138,
#  'dress': -0.7569883813973419,
#  'drink': -0.7518342913145659,
#  'young': -0.7483307494443762,
#  'toss': -0.7449848674541284,
#  'acknowledg': -0.7446434222251502,
#  'edibl': -0.7410165154216042,
#  'someon': -0.7406621885155195,
#  'bouncer': -0.7369606979138059,
#  'melt': -0.7360109135353206,
#  'current': -0.734503338021468,
#  'stood': -0.7341662975407179,
#  'sour': -0.7335466312836612,
#  'note': -0.7331692640244339,
#  'test': -0.7299676811819653,
#  'venu': -0.7288469484523062,
#  'plate': -0.7275115485793036,
#  'self': -0.7270494233822972,
#  'gone': -0.7242719396548017,
#  'complet': -0.7203812703147934,
#  'cupcak': -0.7152230155027124,
#  'limit': -0.7108424669923169,
#  'mad': -0.7095785938857708,
#  'assum': -0.7090223046478669,
#  'meet': -0.7087110625001609,
#  'scottsdal': -0.7082945630506485,
#  'starv': -0.7074344703397849,
#  'unapp': -0.7067005966503819,
#  'flavorless': -0.7060730494979236,
#  'wonton': -0.7057566798586496,
#  'strawberri': -0.7057303960447275,
#  'chow': -0.7023116125152217,
#  'advertis': -0.6995655707387007,
#  'point': -0.6977563186044571,
#  'hand': -0.6967557990636977,
#  'googl': -0.6967034522572868,
#  'nasti': -0.6951196561575319,
#  'burger': -0.6949980730702899,
#  'mean': -0.6898758483752051,
#  'sent': -0.68948378891867,
#  'bed': -0.6881359923764475,
#  'wet': -0.6855576398728532,
#  'vintag': -0.6839178191124067,
#  'theme': -0.6828580868476632,
#  'lettuc': -0.6825381439589944,
#  'long': -0.6819268510459805,
#  'bartend': -0.6812474298451174,
#  'phone': -0.6782077657310137,
#  'eh': -0.6762994335040828,
#  'guacamol': -0.6754195039622695,
#  'switch': -0.6732541308942073,
#  'gratuiti': -0.6727572071744597,
#  'joke': -0.6723149294492453,
#  'spoke': -0.6721636348902025,
#  'hard': -0.6699160559284427,
#  'messi': -0.6675917617415609,
#  'close': -0.6671878388547305,
#  'farm': -0.6632839071907091,
#  'ground': -0.6625844327799609,
#  'salt': -0.6615373770958088,
#  'hill': -0.6570765394833078,
#  'remov': -0.6556519178256484,
#  'shred': -0.6551876867730622,
#  'custom': -0.6550232200091318,
#  'bunch': -0.6543350884299237,
#  'greasi': -0.6542973677487016,
#  'suppos': -0.6539176354789706,
#  'bag': -0.6536462060042526,
#  'need': -0.6513166962343939,
#  'convers': -0.649496474374665,
#  'use': -0.6474948723159419,
#  'encor': -0.6472649385330872,
#  'pull': -0.6469723290887587,
#  'express': -0.646157093831276,
#  'sever': -0.6459825441060704,
#  'et': -0.6457262366127464,
#  'weird': -0.6455283186024283,
#  'yellow': -0.6441722046876803,
#  'frustrat': -0.6399153655040828,
#  'sort': -0.639449995023692,
#  'around': -0.6386096589348406,
#  'forgot': -0.638370134326276,
#  'awkward': -0.6375440281459747,
#  'sat': -0.6367613322227316,
#  'bill': -0.6309000897213517,
#  'began': -0.6304049520417412,
#  'generic': -0.6297328228607032,
#  'pas': -0.6295068297136122,
#  'polici': -0.6293105347883358,
#  'coupon': -0.6286011524880593,
#  'old': -0.6283832544713082,
#  'claim': -0.6283824851704723,
#  'attitud': -0.626311309894232,
#  'cloth': -0.6258564196629532,
#  'dust': -0.6239765564796966,
#  'cheeseburg': -0.6235286371380832,
#  'ined': -0.6234795495638946,
#  'email': -0.6216504881618974,
#  'deserv': -0.6210834296936837,
#  'atmospher': -0.6172150386083713,
#  'door': -0.6163818762656035,
#  'yet': -0.6163490704330722,
#  'accept': -0.6162848253666373,
#  'nightclub': -0.6142250763064667,
#  'hello': -0.6133110826662254,
#  'blow': -0.612871378966064,
#  'tropicana': -0.6121449514944636,
#  'understand': -0.6089722615766631,
#  'salti': -0.6077582478010546,
#  'desir': -0.6076541390066331,
#  'price': -0.6064289265865234,
#  'review': -0.6059637337028844,
#  'filthi': -0.6056290843281918,
#  'yell': -0.6046021772930532,
#  'rental': -0.6044302185848998,
#  'went': -0.5989722779576279,
#  'greas': -0.5978873321213123,
#  'mail': -0.5971273893015617,
#  'que': -0.5961819360288803,
#  'piss': -0.5960134642874874,
#  'oliv': -0.5945346704844637,
#  'felt': -0.5934282540455114,
#  'vraiment': -0.591323846732899,
#  'downhil': -0.5898333804300109,
#  'place': -0.5879550925184055,
#  'steep': -0.5874218656055669,
#  'credit': -0.5861142150917775,
#  'teriyaki': -0.5854138989997767,
#  'skip': -0.584747349350455,
#  'ad': -0.5826736322333415,
#  'sun': -0.5812426028634615,
#  'requir': -0.5805696441072314,
#  'luck': -0.5789755394876523,
#  'mr': -0.5765575877690112,
#  'pedicur': -0.5745169867986675,
#  'serv': -0.5689166188685405,
#  'ass': -0.5678711056107433,
#  'undercook': -0.5662482903904222,
#  'group': -0.5639176759697953,
#  'donut': -0.5637915275057026,
#  'fatti': -0.5629536314364365,
#  'social': -0.5625611916606443,
#  'kung': -0.5616659878671009,
#  'asid': -0.5611300622375642,
#  'tag': -0.5591873669442509,
#  'temp': -0.5580899974589046,
#  'bike': -0.5577895251436323,
#  'line': -0.5577372449915576,
#  'card': -0.5574521314317614,
#  'sign': -0.5547435191648125,
#  'hell': -0.5539279918144049,
#  'glass': -0.5537882110915044,
#  'imposs': -0.5528646369318633,
#  'pot': -0.5521862459815455,
#  'yeah': -0.550865101887204,
#  'clear': -0.5504068461813073,
#  'noisi': -0.5499156217143183,
#  'perhap': -0.549914052403809,
#  'dude': -0.5498952062462941,
#  'crappi': -0.5498012971482317,
#  'sandwich': -0.5487057983281926,
#  'forth': -0.5484206931125578,
#  'sir': -0.5469793001393536,
#  'na': -0.5451841717370287,
#  'longer': -0.5420099321353147,
#  'music': -0.5411898386663903,
#  'walmart': -0.5394205998729885,
#  'dollar': -0.5392265442618313,
#  'chop': -0.5384008338928818,
#  'worth': -0.5374343010797382,
#  'prepar': -0.5329246009224732,
#  'orient': -0.5315279761530256,
#  'didnt': -0.5305013364721869,
#  'silverwar': -0.5288739440694019,
#  'je': -0.5270378941535564,
#  'pathet': -0.5268065879400358,
#  'entir': -0.5242268472679142,
#  'guy': -0.5240481451908048,
#  'whatev': -0.523814287555668,
#  'wait': -0.5236632584684486,
#  'guest': -0.5224590674864518,
#  'bowl': -0.5220864055560782,
#  'desper': -0.5184142100239877,
#  'money': -0.518351349701581,
#  'gotten': -0.5176502222639423,
#  'mislead': -0.5170552247081888,
#  'hundr': -0.5165355461441649,
#  'flavor': -0.5152232899134623,
#  'pleas': -0.5147509995851525,
#  'puff': -0.5136599232020804,
#  'doesnt': -0.5132647393241028,
#  'fake': -0.5114466895450649,
#  'anoth': -0.5105925301425346,
#  'unpleas': -0.5094116692450337,
#  'chair': -0.5068222795215985,
#  'lose': -0.5048985323487349,
#  'station': -0.5046181858407051,
#  'standard': -0.5045677842937895,
#  'empti': -0.5015009912426817,
#  'crap': -0.500881044963745,
#  'much': -0.49906773645589625,
#  'restaur': -0.4986917639019498,
#  'taco': -0.4976546869637254,
#  'probabl': -0.4962850949568971,
#  'call': -0.4926080808840591,
#  'avail': -0.48901324207068864,
#  'smoke': -0.487524842110026,
#  'cheesi': -0.4869772687014704,
#  'vehicl': -0.48601280274905645,
#  'go': -0.48587832155418886,
#  'lazi': -0.48268918324348026,
#  'quit': -0.4821240797663162,
#  'cest': -0.4809451723570583,
#  'schedul': -0.47965874018977694,
#  'exchang': -0.47955093371262747,
#  'medium': -0.47866048736434974,
#  'exampl': -0.4779008121619673,
#  'learn': -0.4767339916788626,
#  'simpl': -0.47637034298279957,
#  'chees': -0.4762113921033563,
#  'basic': -0.4737955268002123,
#  'payless': -0.4726240048601062,
#  'plastic': -0.4720444669270663,
#  'oili': -0.4694239526363332,
#  'imagin': -0.4683605915758944,
#  'simpli': -0.46618103358995644,
#  'pittsburgh': -0.46546143733960854,
#  'extrem': -0.4653169554785437,
#  'caus': -0.46511644375207645,
#  'communiti': -0.46399542888972867,
#  'twice': -0.46346675127282394,
#  'promis': -0.462809739619387,
#  'pour': -0.46229206405260037,
#  'sausag': -0.46195743454373833,
#  'black': -0.46141374443505495,
#  'necessari': -0.4611369379898813,
#  'carri': -0.45974831246252634,
#  'known': -0.45887994299543217,
#  'frank': -0.45880106750774874,
#  'wing': -0.4584629753297196,
#  'adult': -0.458411374944919,
#  'treatment': -0.4573986540088283,
#  'potenti': -0.4565203342512706,
#  'christma': -0.4564328663997446,
#  'pure': -0.455783295717163,
#  'une': -0.4556165233634883,
#  'dj': -0.4548370008760266,
#  'club': -0.45377635763741886,
#  'az': -0.45344449737064924,
#  'hockey': -0.45134053500262017,
#  'chain': -0.44936821546696215,
#  'il': -0.44928234559503744,
#  'contact': -0.4465058437397866,
#  'spend': -0.44601830076994203,
#  'bakeri': -0.4457526251821953,
#  'know': -0.44311036575116375,
#  'messag': -0.4426762628104891,
#  'member': -0.4421498891166921,
#  'avec': -0.44212422694937664,
#  'anytim': -0.4417637120618446,
#  'whole': -0.4415315226651386,
#  'bathroom': -0.4411628716806408,
#  'jean': -0.44053724176334264,
#  'unabl': -0.4397651154523363,
#  'pain': -0.4393212320950216,
#  'mac': -0.43916684784321985,
#  'could': -0.4382291758195533,
#  'anim': -0.4374807505869096,
#  'ring': -0.43628172369064894,
#  'nwe': -0.43513851049881047,
#  'address': -0.43418913113377405,
#  'pictur': -0.43370159579511747,
#  'back': -0.4333702504690282,
#  'drop': -0.4329099921832887,
#  'ribey': -0.43235557093122695,
#  'reheat': -0.42950724484828207,
#  'constant': -0.42891565455241126,
#  'hip': -0.42826146921693625,
#  'desk': -0.4241942957307858,
#  'broth': -0.42335236313533153,
#  'werent': -0.41869826933574816,
#  'waiter': -0.4186635989886059,
#  'overr': -0.4183381665578879,
#  'napkin': -0.4181271840112798,
#  'want': -0.41717314062403177,
#  'chewi': -0.41630148794608623,
#  'dead': -0.41599417622820606,
#  'protein': -0.4156429921184371,
#  'realiz': -0.4148927069137338,
#  'expect': -0.4145887619458855,
#  'goe': -0.4120816016861618,
#  'version': -0.4113169086820549,
#  'inspect': -0.41071143399228893,
#  'bodi': -0.40972768094106043,
#  'ketchup': -0.4084466348596295,
#  'id': -0.4075831519752249,
#  'wan': -0.40545944880509277,
#  'duti': -0.40544647551363944,
#  'spa': -0.40444472058626024,
#  'discount': -0.40256908712653544,
#  'whatsoev': -0.4021894096158128,
#  'strang': -0.40158724798021095,
#  'request': -0.40147040535888895,
#  'smoothi': -0.40062363333254397,
#  'bet': -0.4003824401366113,
#  'tone': -0.39960498015925755,
#  'buddi': -0.39910416284605177,
#  'inch': -0.3980466994970213,
#  'heavi': -0.3978268366983648,
#  'wtf': -0.39718244252676826,
#  'bean': -0.39570329445037067,
#  'consid': -0.39113010689578204,
#  'encount': -0.39099455637587366,
#  'de': -0.3903225424862769,
#  'husband': -0.3902773172760348,
#  'correct': -0.3901094971675464,
#  'nnnot': -0.38926896032855623,
#  'put': -0.38875697989390906,
#  'rate': -0.3876650995285003,
#  'done': -0.38740857605397505,
#  'exit': -0.3863981071554884,
#  'prior': -0.3851956931850089,
#  'disrespect': -0.38376316060969495,
#  'peopl': -0.38371812742905387,
#  'complex': -0.38347624488316345,
#  'here': -0.3830289421685813,
#  'stomach': -0.3828988350998852,
#  'none': -0.3824548719950493,
#  'overlook': -0.3822494300388345,
#  'receipt': -0.3814167567463432,
#  'refus': -0.3811853854421443,
#  'slice': -0.38062599813485076,
#  'ie': -0.37982348619627515,
#  'rack': -0.3796871383794991,
#  'manhattan': -0.37967397478274534,
#  'aroma': -0.37944827447538443,
#  'cuz': -0.3788786285377047,
#  'three': -0.37868522760898493,
#  'browni': -0.37725161266043766,
#  'pile': -0.3770320378469611,
#  'hes': -0.37692013673825636,
#  'nnso': -0.37688828602706914,
#  'attempt': -0.3767234583695168,
#  'ruin': -0.3765269297010656,
#  'wipe': -0.37637662536200023,
#  'throw': -0.3748022844542477,
#  'piec': -0.3746005171509573,
#  'isnt': -0.3745194067481541,
#  'employe': -0.3739808370629978,
#  'carpet': -0.37275337961940525,
#  'ac': -0.37214269918589565,
#  'velvet': -0.3713570344480458,
#  'fait': -0.37115075028763655,
#  'edg': -0.3707059586223512,
#  'nnand': -0.37011611005209377,
#  'updat': -0.36889263785636606,
#  'desert': -0.36472493696844815,
#  'planet': -0.3645439342705611,
#  'extra': -0.36391633448472693,
#  'diner': -0.36338788599446226,
#  'slowli': -0.36310482863668514,
#  'tell': -0.36282161104484956,
#  'milk': -0.3623890376416446,
#  'albeit': -0.3623709945643947,
#  'fact': -0.36136707606890456,
#  'leather': -0.3610582592792573,
#  'youd': -0.36101543338162456,
#  'deli': -0.3599575162350299,
#  'dump': -0.3597008276332719,
#  'tacki': -0.3591845483306512,
#  'ambianc': -0.35896410111962107,
#  'pass': -0.3581236241461404,
#  'garden': -0.3577410346364256,
#  'song': -0.35722368367343393,
#  'appet': -0.35697617463392967,
#  'crowd': -0.3568886050649505,
#  'least': -0.3563014993537726,
#  'forgotten': -0.3561530982193162,
#  'depart': -0.3559250336647964,
#  'engag': -0.3559012824350123,
#  'traffic': -0.35519227817939925,
#  'proceed': -0.3550182234650519,
#  'row': -0.3542089672071755,
#  'happili': -0.35420005325855797,
#  'menus': -0.3538950217833918,
#  'signatur': -0.35303513050795915,
#  'lousi': -0.3524739872061978,
#  'base': -0.3520138010727667,
#  'nnbut': -0.3506162592567002,
#  'cell': -0.34910952023279895,
#  'actual': -0.34896643619297035,
#  'tuna': -0.3473924631409951,
#  'float': -0.3464472670303089,
#  'freakin': -0.3462226820701024,
#  'led': -0.34428941122657664,
#  'declin': -0.3438677524613714,
#  'specialti': -0.3437346286686648,
#  'written': -0.3433374272154117,
#  'xs': -0.34298716934033646,
#  'craft': -0.3421308589039484,
#  'comp': -0.3419645404129581,
#  'drag': -0.3417195260497096,
#  'later': -0.3416385385612062,
#  'hurri': -0.34124682389524646,
#  'quot': -0.3408404769806823,
#  'sauc': -0.34043082550373793,
#  'mgm': -0.33991133553790054,
#  'factor': -0.33923629752355255,
#  'fix': -0.33869801361311014,
#  'india': -0.3384931381449267,
#  'wateri': -0.33812831033243135,
#  'ua': -0.337161502040818,
#  'practic': -0.33463598477633766,
#  'ate': -0.33327094007614494,
#  'stair': -0.3326625806110122,
#  'miss': -0.33156701637206626,
#  'disast': -0.33088048973063955,
#  'sub': -0.3306433684541302,
#  'girlfriend': -0.32886359102314383,
#  'alreadi': -0.32874345566614177,
#  'give': -0.32677596656905494,
#  'hall': -0.3259975826125258,
#  'salami': -0.32545744806573984,
#  'school': -0.3253131243733871,
#  'search': -0.32476882057818396,
#  'weight': -0.3247259393634181,
#  'heck': -0.3246103515281671,
#  'truck': -0.3243365632459711,
#  'margarita': -0.3237434649571116,
#  'counter': -0.3230662509061892,
#  'oven': -0.3221614641703045,
#  'si': -0.3220614015445668,
#  'coke': -0.3215629281680744,
#  'pretzel': -0.3210587482795372,
#  'upset': -0.32020232921612807,
#  'blood': -0.3201201201454839,
#  'enter': -0.32009550633018236,
#  'qui': -0.3183846675743767,
#  'stage': -0.3171971359015867,
#  'press': -0.3168787210235549,
#  'jet': -0.31546267419793517,
#  'gourmet': -0.31539194213153515,
#  'result': -0.31534031419655817,
#  'qualiti': -0.314593239460025,
#  'describ': -0.3135757929023745,
#  'spare': -0.3128767538728534,
#  'establish': -0.3103679132355235,
#  'feta': -0.3099519731692365,
#  'taxi': -0.3098397687429332,
#  'royal': -0.3096905064929182,
#  'care': -0.3088643227302944,
#  'grade': -0.3086885981598422,
#  'nous': -0.3084837698430308,
#  'mat': -0.30834653167065135,
#  'highlight': -0.30830228078528243,
#  'grant': -0.30752852091807537,
#  'um': -0.3072872366637144,
#  'girl': -0.3070944964364691,
#  'forward': -0.30619859085521556,
#  'appl': -0.30437697087526155,
#  'turn': -0.3040835312269604,
#  'common': -0.303483606180333,
#  'inde': -0.3032852776622903,
#  'ue': -0.3031800201028526,
#  'fail': -0.3021862649094593,
#  'paradis': -0.30214378348254606,
#  'pho': -0.3020411771090215,
#  'multipl': -0.3019653039807671,
#  'freezer': -0.30126308229058013,
#  'fuck': -0.30110504276143524,
#  'guin': -0.301062329646948,
#  'game': -0.3004384928314124,
#  'shit': -0.2995687249473691,
#  'last': -0.29818143142031817,
#  'similar': -0.29738596100302,
#  'nthis': -0.2968063139473154,
#  'came': -0.2964851697026185,
#  'excus': -0.29645428275702984,
#  'frozen': -0.295790702542681,
#  'hey': -0.2941290390770511,
#  'kitchen': -0.29334111310148053,
#  'statement': -0.2925783728835359,
#  'women': -0.2917018601540367,
#  'bottom': -0.29071444437815425,
#  'potato': -0.2905777421661306,
#  'onto': -0.2905674984320882,
#  'fit': -0.29050451734933674,
#  'parm': -0.28972315059594256,
#  'count': -0.2883713388714047,
#  'mein': -0.2871658484428734,
#  'gelato': -0.2859417949613986,
#  'togeth': -0.28477004350520685,
#  'montrueal': -0.2841413174517002,
#  'tight': -0.282399672088633,
#  'jack': -0.28163573442846473,
#  'popular': -0.2809157585897363,
#  'asparagus': -0.2785898675036803,
#  'most': -0.27755645542923957,
#  'scratch': -0.27727744424852885,
#  'angri': -0.2765084505901232,
#  'nthe': -0.27605273908099637,
#  'apart': -0.2753136183948293,
#  'rave': -0.2747473956609138,
#  'inn': -0.27434473773258644,
#  'platter': -0.27401681899245955,
#  'near': -0.2733363333226071,
#  'upscal': -0.27311164105417707,
#  'rule': -0.2716310149781995,
#  'restaurantcom': -0.271577105197784,
#  'thru': -0.2706948684118874,
#  'artichok': -0.2691126724617859,
#  'notic': -0.26852392299955197,
#  'woman': -0.26852141850859945,
#  'offer': -0.2678940728064722,
#  'fall': -0.2664860548632126,
#  'product': -0.2662088827872462,
#  'layer': -0.26533862820770004,
#  'despit': -0.2651517249110893,
#  'meal': -0.2647049386436207,
#  'fee': -0.26470159565056417,
#  'mother': -0.2645791189322902,
#  'steak': -0.2641305761463458,
#  'low': -0.26390207965497064,
#  'law': -0.2637284962833151,
#  'owner': -0.2634949509181006,
#  'repeat': -0.26296291259841065,
#  'sui': -0.2627786950341145,
#  'omg': -0.26157327185181095,
#  'downstair': -0.26072079461266273,
#  'butter': -0.2605446319272858,
#  'instead': -0.2605131846654616,
#  'stand': -0.26031491310252897,
#  'needless': -0.2582343996455272,
#  'amen': -0.2569404110495712,
#  'tiramisu': -0.2565673272407357,
#  'mushi': -0.2561691456709356,
#  'balsam': -0.2559856817899381,
#  'speed': -0.2557677417453902,
#  'ce': -0.25567286464950767,
#  'number': -0.2546685102655019,
#  'check': -0.2542558090512706,
#  'step': -0.2541579266845518,
#  'talk': -0.2531699557175478,
#  'els': -0.2522654878765408,
#  'cream': -0.2510232185412759,
#  'act': -0.25095844072168305,
#  'ampl': -0.2506685439840452,
#  'guac': -0.25049323319852207,
#  'laid': -0.2504304625896707,
#  'destin': -0.24949187349516522,
#  'white': -0.24910966532444398,
#  'charm': -0.2488018090073384,
#  'construct': -0.2486969736689583,
#  'websit': -0.24829553348974603,
#  'chunk': -0.24651317503770273,
#  'prosciutto': -0.24643530525556284,
#  'internet': -0.2452401386166384,
#  'resto': -0.24419002054455746,
#  'host': -0.24413075037158313,
#  'happen': -0.24346381220123445,
#  'pea': -0.2430643027925868,
#  'lead': -0.24187277175727875,
#  'groceri': -0.2412241543576151,
#  'foi': -0.24093007692638754,
#  'apolog': -0.24048877035981556,
#  'sashimi': -0.23826216601809264,
#  'death': -0.2378862749051825,
#  'border': -0.23763160361948343,
#  'moment': -0.23736622962240797,
#  'irish': -0.23610534107419304,
#  'kept': -0.2360479876196312,
#  'hadnt': -0.2357304993655755,
#  'danc': -0.2354799666667116,
#  'forev': -0.23511163338461005,
#  'neither': -0.23432118190886075,
#  'friday': -0.23383176932005506,
#  'driver': -0.23343218906217092,
#  'spanish': -0.22835720215682398,
#  'join': -0.22828617214175834,
#  'nowher': -0.22776917163474625,
#  'certain': -0.22771466405325297,
#  'sound': -0.22745530792284874,
#  'mine': -0.2266949616311884,
#  'repli': -0.22403155705034733,
#  'video': -0.22389091243322684,
#  'soda': -0.22219875427922814,
#  'beverag': -0.22212595210691616,
#  'singl': -0.22177475239080624,
#  'receptionist': -0.2216208685493422,
#  'moi': -0.22157853564199106,
#  'chorizo': -0.21936143284822032,
#  'femal': -0.2187929291136349,
#  'garbag': -0.2187284765873992,
#  'avocado': -0.21822617090017976,
#  'comment': -0.21799302345694052,
#  'golf': -0.21401075483657211,
#  'descript': -0.21340505149682465,
#  'shirt': -0.213247634664599,
#  'hint': -0.21316256393752664,
#  'mont': -0.2129302844020433,
#  'soso': -0.21260281767609057,
#  'co': -0.21259254448504683,
#  'major': -0.212203081916605,
#  'uncomfort': -0.2121083940867418,
#  'mueam': -0.21112668263877132,
#  'voic': -0.20966841103480147,
#  'everytim': -0.20826334380200773,
#  'leur': -0.20494848294067225,
#  'replac': -0.204054662766474,
#  'aka': -0.20400074645434937,
#  'afterward': -0.20333026356038117,
#  'design': -0.2026766431060259,
#  'ba': -0.20141550016400694,
#  'ceil': -0.20093217298858163,
#  'closest': -0.2006327118719162,
#  'towel': -0.20030576450669943,
#  'over': -0.2002461798443169,
#  'hotel': -0.20003700318280365,
#  'band': -0.19864535728639776,
#  'infect': -0.1979855191224537,
#  'hr': -0.19788685072778556,
#  'advic': -0.19579909162253833,
#  'aria': -0.19549132488767557,
#  'gilbert': -0.1950853146700381,
#  'tattoo': -0.19503250425746027,
#  'everywher': -0.19396501550015072,
#  'secur': -0.19359587855410534,
#  'obnoxi': -0.19319746960160625,
#  'rush': -0.19306829836459058,
#  'en': -0.19253006933231312,
#  'cole': -0.19211879470849794,
#  'store': -0.19113266897102324,
#  'buy': -0.19063757351303792,
#  'hop': -0.19034397286052282,
#  'insur': -0.1903047486076926,
#  'stare': -0.1901782612210649,
#  'skinni': -0.1901445591228048,
#  'squar': -0.18986961619021672,
#  'laugh': -0.18948999583981363,
#  'took': -0.18889942427702677,
#  'agre': -0.18821879819698056,
#  'button': -0.18801345518115226,
#  'gas': -0.187835035190889,
#  'fanci': -0.18779395539350563,
#  'uea': -0.18769294234724648,
#  'temperatur': -0.18746150374154563,
#  'du': -0.1869933526613224,
#  'chang': -0.18611983473554086,
#  'situat': -0.18566794677322324,
#  'hallway': -0.18561492902690718,
#  'jai': -0.18435625706003056,
#  'queen': -0.1843283139962387,
#  'kick': -0.18401004491614703,
#  'smaller': -0.18377564831695295,
#  'duecor': -0.18360597235608173,
#  'move': -0.1835018506062549,
#  'stock': -0.1825663752525673,
#  'chat': -0.18246888558737814,
#  'term': -0.18145442528164413,
#  'health': -0.18123903590813795,
#  'brown': -0.18092579559970212,
#  'sheet': -0.1806140927027289,
#  'pretenti': -0.17937971835430813,
#  'mayo': -0.1788422370699561,
#  'pasta': -0.17862886106691728,
#  'groupon': -0.1776194929693149,
#  'hang': -0.17624345286348736,
#  'mind': -0.17619868723692036,
#  'falafel': -0.17480178143045746,
#  'son': -0.17396902675538373,
#  'regardless': -0.1739398685673466,
#  'alon': -0.17364048684882002,
#  'cute': -0.17291835513579473,
#  'entranc': -0.172704914755696,
#  'somewhat': -0.17139133205354629,
#  'larg': -0.16944395012992414,
#  'croissant': -0.1671629824649256,
#  'brunch': -0.16711546055279286,
#  'etc': -0.16651009041951087,
#  'retail': -0.16529476964418335,
#  'whether': -0.16527396747532455,
#  'river': -0.16465092656906927,
#  'lie': -0.16397072650734595,
#  'eager': -0.16327044253680442,
#  'holiday': -0.161713612998478,
#  'equip': -0.16162581631754358,
#  'mini': -0.15891527242861034,
#  'across': -0.15825402146066594,
#  'present': -0.15819455463942333,
#  'tequila': -0.15775140158339812,
#  'strong': -0.15757300341856467,
#  'rid': -0.15685881793119483,
#  'decid': -0.15543987801120518,
#  'fellow': -0.1548879868172179,
#  'favourit': -0.154873772745771,
#  'rock': -0.15403447169668508,
#  'pint': -0.15362015379187033,
#  'hung': -0.15216846849821905,
#  'name': -0.15209262493672948,
#  'chowder': -0.15176296287362875,
#  'burnt': -0.15089306973132532,
#  'cabbag': -0.1503607110711364,
#  'theyll': -0.1503122987557277,
#  'nest': -0.14952706822141262,
#  'app': -0.14777564413718594,
#  'polit': -0.14741460629225606,
#  'clientel': -0.14725510717142112,
#  'question': -0.14724862117095108,
#  'crew': -0.14674850256098892,
#  'mojo': -0.14674572571887526,
#  'carrot': -0.1463962065218379,
#  'studio': -0.14628280055006146,
#  'prefer': -0.14612130502475318,
#  'uetait': -0.1460609159996065,
#  'explan': -0.14558285974655755,
#  'kudo': -0.14432914644671643,
#  'tomato': -0.14198302137009552,
#  'month': -0.14175387031328948,
#  'child': -0.14156228405182655,
#  'tab': -0.13821098899237105,
#  'cashier': -0.1358196291004203,
#  'butteri': -0.1347474589865698,
#  'appeal': -0.13459095291142195,
#  'corpor': -0.13439921884748462,
#  'bath': -0.13349256860048234,
#  'mountain': -0.13223902395579126,
#  'quand': -0.13217475689513225,
#  'waitstaff': -0.13070076745753845,
#  'nut': -0.1303313506486864,
#  'hi': -0.1297478845140365,
#  'hassl': -0.1296635126406709,
#  'nd': -0.12956187224664917,
#  'mari': -0.129366418666673,
#  'btw': -0.12878437084231822,
#  'entri': -0.12811028563916088,
#  'natur': -0.12797787163008129,
#  'difficult': -0.12771866142771493,
#  'fair': -0.127238281886861,
#  'flag': -0.1266980582829683,
#  'shop': -0.12645593811013656,
#  'batter': -0.12608177197305354,
#  'rest': -0.12557363393985738,
#  'scrambl': -0.12551826309179678,
#  'neat': -0.12465446440302172,
#  'damag': -0.12457333685240053,
#  'nn': -0.12385837963630691,
#  'industri': -0.12341728659772112,
#  'yuck': -0.12264285337977879,
#  'earn': -0.12235950301071594,
#  'half': -0.12217876373250261,
#  'clue': -0.12140209736836727,
#  'return': -0.12026292991209327,
#  'cat': -0.1201699136176766,
#  'bacon': -0.11910695979607197,
#  'courteous': -0.11848048783888784,
#  'slide': -0.11757556504225501,
#  'benedict': -0.11743835651194393,
#  'seul': -0.11686169131688774,
#  'takeout': -0.11661686580844732,
#  'fishi': -0.11661285789960152,
#  'gon': -0.11578412074924294,
#  'cheaper': -0.11567795830560501,
#  'fruit': -0.11552335416312198,
#  'hear': -0.11520576505535413,
#  'onlin': -0.11474070318322553,
#  'push': -0.11460300196619991,
#  'restroom': -0.11455979343778944,
#  'wave': -0.11426219018152833,
#  'behind': -0.11394493798608313,
#  'numer': -0.11388949324185643,
#  'fridg': -0.11388918726035095,
#  'hush': -0.11251981213352669,
#  'occas': -0.11175630155743621,
#  'packag': -0.11135371642431088,
#  'former': -0.11130846051630061,
#  'puppi': -0.1104751563223138,
#  'everyday': -0.11024211107349602,
#  'drunk': -0.1101783527487131,
#  'sont': -0.10851114476138154,
#  'basi': -0.10779519509337598,
#  'valet': -0.10777316108171037,
#  'nnone': -0.10766338776728293,
#  'lime': -0.10648481317774793,
#  'cuisin': -0.10441063158053152,
#  'steer': -0.10399742028563888,
#  'tout': -0.10356343156814576,
#  'nnwhile': -0.10345391880999133,
#  'spit': -0.10313430998906953,
#  'reason': -0.10293379304974862,
#  'layout': -0.10290106868013384,
#  'instal': -0.10153305442960404,
#  'pancak': -0.10137034215030985,
#  'crab': -0.10135013499727677,
#  'cilantro': -0.10103782042044493,
#  'parti': -0.1002132877545476,
#  'parent': -0.09927221928973592,
#  'bank': -0.09862331253997997,
#  'boil': -0.09850295897031272,
#  'fish': -0.0977310598713889,
#  'grit': -0.0974833593327813,
#  'pair': -0.09738359957812165,
#  'due': -0.09716223135062904,
#  'catch': -0.09638478983853821,
#  'public': -0.09614134922173437,
#  'tabl': -0.09446708126108014,
#  'remot': -0.09413001639439122,
#  'state': -0.09374065532938203,
#  'honor': -0.09362253618193433,
#  'direct': -0.09270773793471501,
#  'june': -0.09243213832170208,
#  'quesadilla': -0.09204325519748743,
#  'upon': -0.09106688930496055,
#  'deep': -0.09084800428600828,
#  'irrit': -0.09042925117679318,
#  'offic': -0.09041400995912327,
#  'air': -0.09041037320766848,
#  'macaroni': -0.09022096446661007,
#  'spoil': -0.09017056302513858,
#  'thrown': -0.08995601180478063,
#  'hooter': -0.08987149449742926,
#  'sit': -0.08968956806590736,
#  ...}

# %%
## 사전 정규화

def dict_normalize(score_dict):
  dict_ = score_dict.copy()
  key = list(dict_.keys())
  value = np.array(list(dict_.values()))
  value /= np.max(abs(value))
  normalize_dict = {k:v for k, v in zip(key, value)} 
  return normalize_dict

normalize_dict = dict_normalize(score_dict)

# %%
## 사전에서 coefficient가 0.1 이상의 단어들을 긍정 혹은 부정으로 분리

pos_ = {}
neg_ = {}

for (k,v) in score_dict:
# for k, v in normalize_dict.items():
  if abs(v)> 0.1:
    if v < 0:
      pos_[k] = v
    elif v > 0:
      neg_[k] = v
    else :
      None

print(len(pos_),len(neg_))
# Out:
# 958 893

# %%
sorted(pos_.items(),reverse=False ,key=operator.itemgetter(1))
# Out:
# [('instead', -2.36226700816096),
#  ('ruin', -2.2949313958452935),
#  ('wast', -2.285412972856424),
#  ('spawn', -2.255371329886774),
#  ('noth', -2.243987656797461),
#  ('worst', -2.208652107624983),
#  ('broken', -2.1793688272315843),
#  ('fallout', -2.170272978765479),
#  ('moba', -2.1236260668284648),
#  ('sniper', -2.0480161788188873),
#  ('whole', -2.0148891035055327),
#  ('pay', -1.9921180342793867),
#  ('wasnt', -1.9165441779940129),
#  ('gun', -1.877262649796373),
#  ('even', -1.8352319180935988),
#  ('terribl', -1.8295471735703919),
#  ('dweller', -1.7389400730520221),
#  ('sad', -1.73670096000283),
#  ('smite', -1.7208977173339468),
#  ('slow', -1.7101385583104698),
#  ('uninstal', -1.6905474026049956),
#  ('reviewi', -1.6860181475293572),
#  ('ban', -1.6813013112389745),
#  ('forc', -1.6555156074488835),
#  ('cost', -1.6517635503342305),
#  ('cant', -1.6222017101163824),
#  ('camp', -1.6053398343221157),
#  ('develop', -1.5816219749294587),
#  ('shot', -1.5559270910371297),
#  ('poor', -1.5556823767095842),
#  ('went', -1.5453983714708064),
#  ('garbag', -1.5286698038363158),
#  ('posit', -1.4984691583220224),
#  ('resourc', -1.4791217428715475),
#  ('vault', -1.477159508277155),
#  ('kill', -1.4517504279778843),
#  ('front', -1.4475595529404743),
#  ('issu', -1.4394237987345457),
#  ('af', -1.4357897535119672),
#  ('might', -1.4320157113983183),
#  ('st', -1.4267919685038166),
#  ('back', -1.4040912279362734),
#  ('imposs', -1.3978175555899257),
#  ('potenti', -1.3954315611321735),
#  ('match', -1.3850387533204804),
#  ('remov', -1.3800798922728352),
#  ('disconnect', -1.3449489562826518),
#  ('dead', -1.343449381386358),
#  ('pain', -1.3359159921750354),
#  ('unless', -1.3349007400880082),
#  ('money', -1.3268347325963268),
#  ('car', -1.3264633537212809),
#  ('unbalanc', -1.322611923582301),
#  ('delet', -1.3159559618172465),
#  ('clunki', -1.3067545809242378),
#  ('horribl', -1.2989251689831052),
#  ('wors', -1.2955261745261195),
#  ('ridicul', -1.294830031616082),
#  ('point', -1.2720782884461765),
#  ('wall', -1.2649281351484118),
#  ('didnt', -1.2631973020753453),
#  ('balanc', -1.260660182186164),
#  ('matter', -1.251576564253932),
#  ('design', -1.2479751465087863),
#  ('bad', -1.2399060106035331),
#  ('yugioh', -1.2329303922001629),
#  ('ww', -1.2248747768237584),
#  ('gb', -1.2195039928325786),
#  ('nightmar', -1.217260041751097),
#  ('none', -1.2156185058992266),
#  ('zombi', -1.2125904981631908),
#  ('robocraft', -1.2079585649396036),
#  ('bother', -1.1867493144651813),
#  ('weapon', -1.181751836097218),
#  ('crap', -1.1759999901645382),
#  ('shame', -1.1710455507914288),
#  ('unplay', -1.1703401630491748),
#  ('beginn', -1.1618141933198232),
#  ('aw', -1.1608253039894894),
#  ('freeear', -1.1557751877733815),
#  ('idea', -1.1516203333802009),
#  ('rifl', -1.1455097117540254),
#  ('anyth', -1.1440704001102548),
#  ('joke', -1.1440528705781583),
#  ('oh', -1.1207567320433143),
#  ('report', -1.1104830443929625),
#  ('infest', -1.1053695211495398),
#  ('cancer', -1.1024675434803035),
#  ('hirez', -1.0971279958403717),
#  ('toxic', -1.0939849764957077),
#  ('pure', -1.0900536579921718),
#  ('andor', -1.0889737523978962),
#  ('session', -1.0877520226138915),
#  ('until', -1.0844050453514973),
#  ('page', -1.081755441884937),
#  ('state', -1.07820321126847),
#  ('crate', -1.0706289696998001),
#  ('liter', -1.0704682995444796),
#  ('crash', -1.0661435806325954),
#  ('reason', -1.0656272184531559),
#  ('chang', -1.0600174772334732),
#  ('mediocr', -1.055309456949118),
#  ('player', -1.0484781855907341),
#  ('duel', -1.043548214820258),
#  ('dont', -1.03841312648915),
#  ('hi', -1.0370811739862351),
#  ('make', -1.0364586180833915),
#  ('third', -1.0326856326190472),
#  ('silver', -1.0288564160824918),
#  ('common', -1.02481336228746),
#  ('suffer', -1.024570467756702),
#  ('els', -1.0240411652745496),
#  ('awar', -1.0182037665265273),
#  ('awhil', -1.0139468937399432),
#  ('unfortun', -1.013224440384854),
#  ('grind', -0.9979937880047065),
#  ('inform', -0.9871216034267848),
#  ('name', -0.9829482083696446),
#  ('gavno', -0.9828651356154848),
#  ('either', -0.9789847191379785),
#  ('downhil', -0.9785015549837388),
#  ('way', -0.9776123389680699),
#  ('stupid', -0.9756933398937989),
#  ('dev', -0.9723419418090117),
#  ('minut', -0.9703442889268938),
#  ('wouldnt', -0.962532368546899),
#  ('bare', -0.9621384995346389),
#  ('updat', -0.9617127968046415),
#  ('form', -0.959475803243123),
#  ('cheat', -0.9561721011982508),
#  ('fck', -0.955702956808455),
#  ('infantri', -0.9552168446243575),
#  ('buck', -0.9511055553074848),
#  ('given', -0.9477446816530863),
#  ('rid', -0.9442540612747127),
#  ('left', -0.9432022419844457),
#  ('overpr', -0.9331853888674887),
#  ('menu', -0.933024798909643),
#  ('ta', -0.9310668546341172),
#  ('pair', -0.9281784277080354),
#  ('sort', -0.9272246984606255),
#  ('lack', -0.9270546705317807),
#  ('begin', -0.9195470328881861),
#  ('greedi', -0.9168085458535233),
#  ('rat', -0.9163219063749966),
#  ('lame', -0.9153917049559268),
#  ('que', -0.9152106759052555),
#  ('text', -0.9131250479145245),
#  ('dissapoint', -0.9112278671459102),
#  ('save', -0.910612451208109),
#  ('buy', -0.9063722642633998),
#  ('robot', -0.9055707549122981),
#  ('bs', -0.9019302443604826),
#  ('continu', -0.9009950624715042),
#  ('repair', -0.8999093832478189),
#  ('wish', -0.8997242644673664),
#  ('seem', -0.899145050832627),
#  ('made', -0.8990791518191827),
#  ('accuraci', -0.8961445008856098),
#  ('spent', -0.8931093604690358),
#  ('konami', -0.891944965073987),
#  ('price', -0.8904241155303998),
#  ('hacker', -0.8899770449701174),
#  ('someth', -0.8880009208464169),
#  ('fall', -0.886245962879756),
#  ('para', -0.8833362985491198),
#  ('super', -0.8832806842159296),
#  ('download', -0.8781594126306971),
#  ('stay', -0.8764301515988434),
#  ('attempt', -0.8753742028854913),
#  ('nuka', -0.8732643404133406),
#  ('food', -0.868074734436691),
#  ('mess', -0.8664266470730858),
#  ('absolut', -0.8659053407933859),
#  ('deck', -0.865892448183206),
#  ('shelter', -0.8654037568191516),
#  ('bore', -0.8616161544959536),
#  ('buggi', -0.8595661975421476),
#  ('ultra', -0.8585052335911822),
#  ('greed', -0.8572654246266347),
#  ('edit', -0.8559450165168442),
#  ('drain', -0.8555918330636936),
#  ('suck', -0.8548167849086952),
#  ('panther', -0.8546945478162145),
#  ('sell', -0.8534880285346327),
#  ('use', -0.8531658972170244),
#  ('season', -0.8529220668816788),
#  ('nowher', -0.8526708040665409),
#  ('tag', -0.8513406260475943),
#  ('confus', -0.8512373504811187),
#  ('sht', -0.8506478471262781),
#  ('legendari', -0.8467410895513483),
#  ('final', -0.8461793150286545),
#  ('realis', -0.8457980356716979),
#  ('sold', -0.8435077774847499),
#  ('cap', -0.8420976723054703),
#  ('cheater', -0.8395215044534523),
#  ('stomp', -0.8391870263686736),
#  ('hack', -0.8357738420859245),
#  ('euro', -0.834966950943104),
#  ('factor', -0.8343701481436023),
#  ('mean', -0.831197084671376),
#  ('avoid', -0.8304867091460021),
#  ('charg', -0.829377437842713),
#  ('part', -0.8279875381934889),
#  ('anymor', -0.8267641892101653),
#  ('sea', -0.8253784409834372),
#  ('survivor', -0.8223307872223837),
#  ('low', -0.8211806354793759),
#  ('lose', -0.8209644756845353),
#  ('direct', -0.8191174991477017),
#  ('america', -0.8167409311601883),
#  ('member', -0.8167226207245043),
#  ('behavior', -0.8164186265516135),
#  ('past', -0.8153608016880525),
#  ('longer', -0.8139020834275899),
#  ('exp', -0.8062113250894818),
#  ('mr', -0.8039773395744981),
#  ('step', -0.8030296286269311),
#  ('paid', -0.8029969200883782),
#  ('trap', -0.802585340846359),
#  ('server', -0.801866892845792),
#  ('old', -0.8007959282982209),
#  ('bms', -0.7923924873688755),
#  ('complet', -0.7890400126422056),
#  ('god', -0.7882198190940508),
#  ('mind', -0.7873495944449289),
#  ('mid', -0.7861421886846526),
#  ('languag', -0.7831818856366661),
#  ('describ', -0.7804970618628312),
#  ('frustrat', -0.7797792880054784),
#  ('locat', -0.7776327595739094),
#  ('trash', -0.774543570195999),
#  ('qualiti', -0.7685526941753756),
#  ('gem', -0.7683687432172461),
#  ('goodby', -0.7679713155418051),
#  ('paytowin', -0.7597044115940929),
#  ('soo', -0.7565839423012963),
#  ('twice', -0.7557315415472365),
#  ('matchmak', -0.7550902424364115),
#  ('couldnt', -0.752293779914046),
#  ('mayb', -0.7494800634069345),
#  ('anoth', -0.7473290285435361),
#  ('block', -0.7469354153187476),
#  ('explan', -0.7468757705427225),
#  ('fork', -0.7467653319454244),
#  ('ftp', -0.7462365969819122),
#  ('ed', -0.7435121105255222),
#  ('cash', -0.7434352088507237),
#  ('squad', -0.7411211853662427),
#  ('stamina', -0.7406087816736837),
#  ('trion', -0.7364140110660242),
#  ('manag', -0.7336498720636122),
#  ('automat', -0.7301459661762845),
#  ('worthless', -0.7290269540613321),
#  ('file', -0.7289858397362284),
#  ('becom', -0.7280635154253697),
#  ('reto', -0.7279088352796571),
#  ('brought', -0.7269891176628152),
#  ('detect', -0.7267620996346396),
#  ('compet', -0.7262102548194621),
#  ('plain', -0.7260890476982735),
#  ('earlier', -0.7255762743765292),
#  ('grab', -0.72529226824647),
#  ('room', -0.7186187949208642),
#  ('lost', -0.7180512521160313),
#  ('frame', -0.7175495987557604),
#  ('error', -0.7165170035815543),
#  ('turn', -0.7074746057088884),
#  ('gambl', -0.706053840724118),
#  ('moment', -0.7058083323921128),
#  ('dayz', -0.7048947716834277),
#  ('hitbox', -0.7037368175799509),
#  ('grindi', -0.7030069713262754),
#  ('disappoint', -0.7004642098491188),
#  ('second', -0.6999509822858838),
#  ('brotherhood', -0.6994085611647517),
#  ('bug', -0.6962622163135714),
#  ('wont', -0.6954745693261446),
#  ('highest', -0.694061554982218),
#  ('shoot', -0.6925415867958362),
#  ('away', -0.6921459030931674),
#  ('becuas', -0.6915906812073468),
#  ('cpu', -0.6911653215124297),
#  ('nope', -0.689931206254834),
#  ('optim', -0.6874213159324495),
#  ('acquir', -0.6873712255915321),
#  ('store', -0.6852983414584911),
#  ('build', -0.6850820181857948),
#  ('decis', -0.6844930951284963),
#  ('explain', -0.682719693714507),
#  ('constant', -0.6817213706396982),
#  ('milk', -0.6815079025874479),
#  ('gg', -0.6813622732457507),
#  ('cola', -0.6787205953201502),
#  ('gone', -0.6771160328685556),
#  ('program', -0.6759495268536093),
#  ('camper', -0.6672075736309531),
#  ('thrown', -0.665944383398903),
#  ('simpli', -0.663148427280864),
#  ('gunplay', -0.6600167478570927),
#  ('allow', -0.6597953064083626),
#  ('freejam', -0.6597056079520693),
#  ('credit', -0.6595725875537175),
#  ('older', -0.6574234395500781),
#  ('alpha', -0.6567240653346067),
#  ('tldr', -0.6561739954237951),
#  ('year', -0.6553446231518303),
#  ('tutori', -0.654981927252048),
#  ('germani', -0.6544248163787494),
#  ('mobil', -0.6509805920297806),
#  ('stope', -0.6507770810560852),
#  ('finish', -0.6506097516228616),
#  ('count', -0.6489865227292886),
#  ('instant', -0.6486873684740158),
#  ('shadowvers', -0.6467366899678186),
#  ('glad', -0.6466101915854421),
#  ('pile', -0.6466007854769878),
#  ('zero', -0.6457863940678867),
#  ('blind', -0.6457785976362939),
#  ('farm', -0.6401804973142992),
#  ('pop', -0.638761089690885),
#  ('start', -0.6331698236053068),
#  ('passiv', -0.6308593354333362),
#  ('junk', -0.6308068126091715),
#  ('everytim', -0.630727997254526),
#  ('eac', -0.6302192538073714),
#  ('connect', -0.6271214208912669),
#  ('what', -0.6267805949349323),
#  ('row', -0.6266200147678989),
#  ('etern', -0.6243446937581616),
#  ('short', -0.6227024475429295),
#  ('enter', -0.6225956540203543),
#  ('rd', -0.6214554934286945),
#  ('support', -0.6205523223001788),
#  ('luck', -0.6183336000933344),
#  ('cuz', -0.6178421717837058),
#  ('loos', -0.6166509267966661),
#  ('falcon', -0.616064847356541),
#  ('warthund', -0.6160569103405538),
#  ('vehicl', -0.6148271453502404),
#  ('realiz', -0.614360739043185),
#  ('patch', -0.6092458538883917),
#  ('felt', -0.608971823248851),
#  ('goe', -0.6083263019357917),
#  ('live', -0.6074918475983223),
#  ('dumb', -0.6071217477156303),
#  ('reach', -0.6041620818906307),
#  ('aspect', -0.6009456489701627),
#  ('function', -0.5948790252948764),
#  ('theyv', -0.5925397507324203),
#  ('overpow', -0.5908676913160861),
#  ('conquest', -0.5897208993061835),
#  ('leagu', -0.5888341908500525),
#  ('russian', -0.5881110781626477),
#  ('wtf', -0.5878124801036197),
#  ('softwar', -0.5851434240243625),
#  ('asset', -0.5840537684772222),
#  ('singl', -0.5840334985410941),
#  ('die', -0.5838424138465242),
#  ('nd', -0.5816062624432856),
#  ('pool', -0.5786243447660848),
#  ('want', -0.5779264192451561),
#  ('known', -0.5759928200565434),
#  ('minimum', -0.5747956695413421),
#  ('forum', -0.5717595360767833),
#  ('power', -0.5699252285873996),
#  ('forgot', -0.5674175715377138),
#  ('major', -0.5661703715876476),
#  ('sever', -0.5640535888794105),
#  ('exampl', -0.5638478211400569),
#  ('hungri', -0.5636719671807975),
#  ('okay', -0.561083447029082),
#  ('membership', -0.5542848657114418),
#  ('releas', -0.553424776207049),
#  ('iron', -0.5530720729361627),
#  ('desktop', -0.5518715971305208),
#  ('underpow', -0.5509715084539119),
#  ('fix', -0.550071344677728),
#  ('coupl', -0.5493923699075411),
#  ('experi', -0.5487352750478831),
#  ('encourag', -0.5485797943743669),
#  ('copi', -0.547690696157138),
#  ('witch', -0.5474489148682259),
#  ('reviv', -0.546832044636768),
#  ('mainten', -0.5467788546727537),
#  ('pistol', -0.5453864768198521),
#  ('chanc', -0.5451061083802877),
#  ('aka', -0.5445782724194407),
#  ('near', -0.5428556249275078),
#  ('fact', -0.5420961435239402),
#  ('wait', -0.5420407804565117),
#  ('restart', -0.5417655709793898),
#  ('admit', -0.5406291329303481),
#  ('duti', -0.5397199529764707),
#  ('fps', -0.5381106189138726),
#  ('impress', -0.5363904582473553),
#  ('respawn', -0.5347255387168168),
#  ('rare', -0.5321481770035952),
#  ('box', -0.5317109094680698),
#  ('scam', -0.5315498461395504),
#  ('mp', -0.5301246157817948),
#  ('insan', -0.5290504074470432),
#  ('post', -0.5258708696604265),
#  ('essenti', -0.5253585901376917),
#  ('vision', -0.5252436536881157),
#  ('movement', -0.5250832362732379),
#  ('summon', -0.5250355784316444),
#  ('repeat', -0.5249348120053224),
#  ('insid', -0.5237682149079296),
#  ('gold', -0.5236770983778973),
#  ('ya', -0.5212077576273221),
#  ('useless', -0.5194925319856827),
#  ('creatur', -0.5182978773961284),
#  ('newcom', -0.5181614637235767),
#  ('go', -0.5147005451148646),
#  ('googl', -0.5103617921968466),
#  ('arm', -0.5102568311877799),
#  ('favor', -0.5065492259161508),
#  ('behind', -0.5062170024842465),
#  ('age', -0.5054555763287032),
#  ('na', -0.5047335434217946),
#  ('holi', -0.5046612251500063),
#  ('royal', -0.5033229621062973),
#  ('told', -0.502369775868494),
#  ('expens', -0.5008804829039941),
#  ('everywher', -0.49882862682464957),
#  ('everi', -0.49848803268465064),
#  ('folk', -0.49812943852284913),
#  ('yesterday', -0.49806941977319763),
#  ('replac', -0.4980097090881985),
#  ('suppos', -0.4967256520175397),
#  ('min', -0.4950568122142184),
#  ('arma', -0.4950122127647312),
#  ('sink', -0.4946293564179683),
#  ('charm', -0.4910505591821781),
#  ('unstabl', -0.489492938118416),
#  ('assum', -0.48867682385347444),
#  ('ing', -0.48857882801430597),
#  ('concept', -0.4881913955901772),
#  ('hundr', -0.487661702878464),
#  ('end', -0.48711102621799923),
#  ('ribbon', -0.48662175216522086),
#  ('utter', -0.48571226703627957),
#  ('ai', -0.485604118707952),
#  ('blue', -0.4832832846730877),
#  ('reviewthi', -0.47990148957737055),
#  ('push', -0.4791677742669166),
#  ('warz', -0.47863402796061055),
#  ('camera', -0.47523600595316057),
#  ('itif', -0.47402611367959),
#  ('draw', -0.4727781013923962),
#  ('valu', -0.4716655963698084),
#  ('creator', -0.47057403892207994),
#  ('frank', -0.4702127166947404),
#  ('whale', -0.4696932325594325),
#  ('cut', -0.46832383621702317),
#  ('cannon', -0.46731178070233054),
#  ('longtim', -0.46562036728371303),
#  ('fed', -0.4652189927599655),
#  ('dynam', -0.46488375233060225),
#  ('two', -0.4648423798042214),
#  ('south', -0.4615367565534768),
#  ('ratio', -0.45692760670201527),
#  ('char', -0.4550876220723008),
#  ('cover', -0.45427912256773473),
#  ('opposit', -0.4535469653891411),
#  ('pathet', -0.4517361245497087),
#  ('becam', -0.4496092229817392),
#  ('newer', -0.44842668193170937),
#  ('otherwis', -0.44834824051393724),
#  ('kind', -0.44441394300150683),
#  ('ish', -0.4442556975619497),
#  ('hrs', -0.4440505967474585),
#  ('status', -0.44394208602688756),
#  ('set', -0.4439291890557082),
#  ('kept', -0.44372165521481816),
#  ('blame', -0.4429914064094458),
#  ('mod', -0.44274126256003965),
#  ('blown', -0.4400460361557038),
#  ('war', -0.4393801331464192),
#  ('edg', -0.4382570248257836),
#  ('ladder', -0.43817985630900413),
#  ('irl', -0.4380221525456276),
#  ('water', -0.43798654425053696),
#  ('reviewth', -0.43795976842468176),
#  ('audio', -0.4378598863510945),
#  ('loot', -0.4377393190755561),
#  ('laugh', -0.4363255805543801),
#  ('hz', -0.4349851585883195),
#  ('ask', -0.43450658553718685),
#  ('wise', -0.43318105953762187),
#  ('catch', -0.4325308953570912),
#  ('crappi', -0.43232099408574776),
#  ('enemi', -0.43137220323551545),
#  ('hole', -0.4312678543518965),
#  ('readi', -0.4311839134884129),
#  ('user', -0.43084468286700456),
#  ('riddl', -0.4304550326203915),
#  ('counter', -0.4303250703881037),
#  ('blocki', -0.43030440654312085),
#  ('russia', -0.4302325521074413),
#  ('shall', -0.42757520191973264),
#  ('last', -0.426097805092907),
#  ('flag', -0.42536495577335914),
#  ('dozen', -0.42534718560597695),
#  ('bomb', -0.4251830057097679),
#  ('nobodi', -0.42498125205261517),
#  ('king', -0.4248622058403981),
#  ('ugli', -0.4238762051895976),
#  ('megabot', -0.42245205818410353),
#  ('care', -0.4193590199323828),
#  ('es', -0.41739885427048445),
#  ('reali', -0.4172149711095949),
#  ('track', -0.41684481029204246),
#  ('instal', -0.4141827814691777),
#  ('time', -0.41339650859208377),
#  ('occasion', -0.41121472675157855),
#  ('fewer', -0.40978492969199715),
#  ('web', -0.40947453923831983),
#  ('head', -0.40696154972542087),
#  ('micro', -0.40688131572337827),
#  ('lead', -0.4068350618398765),
#  ('freez', -0.4065724608998393),
#  ('system', -0.4048622482863631),
#  ('grindfest', -0.4045847598655642),
#  ('least', -0.4036222728256029),
#  ('pro', -0.40353549388915266),
#  ('joust', -0.4033659385086228),
#  ('albeit', -0.4031636231285314),
#  ('fit', -0.4024627696994158),
#  ('rule', -0.40206063682778426),
#  ('argu', -0.40134394368924914),
#  ('process', -0.39899441096475785),
#  ('refus', -0.3989423386580495),
#  ('unabl', -0.3986074221663225),
#  ('monitor', -0.3983680489324031),
#  ('ptrd', -0.3978397830775583),
#  ('alreadi', -0.3972803005332026),
#  ('meh', -0.39612047382070176),
#  ('theori', -0.3951935528165421),
#  ('itll', -0.39131493861093525),
#  ('economi', -0.3901487976812312),
#  ('en', -0.38953232409175187),
#  ('anti', -0.38919335130686195),
#  ('lowest', -0.38796545995544823),
#  ('suppli', -0.3866798890517966),
#  ('absurd', -0.38133272194153195),
#  ('data', -0.3808188059667701),
#  ('dollar', -0.37994206127400254),
#  ('reviewit', -0.3792916563704608),
#  ('whoever', -0.3792793296132932),
#  ('sight', -0.3778388197068021),
#  ('except', -0.3772017748594415),
#  ('redicul', -0.3750968610160871),
#  ('pls', -0.3737816132280084),
#  ('destroy', -0.37160752216786186),
#  ('spam', -0.37127530243159457),
#  ('sourc', -0.3708343902013216),
#  ('exact', -0.36957686648435967),
#  ('surviv', -0.3694838444960836),
#  ('despit', -0.36918768152751164),
#  ('rough', -0.3688616240336662),
#  ('latest', -0.3688490456436281),
#  ('hour', -0.3675532178152033),
#  ('appar', -0.3666119919343557),
#  ('dog', -0.3658433962535943),
#  ('know', -0.3652670644043373),
#  ('eg', -0.3645460674853193),
#  ('transfer', -0.36450953684266146),
#  ('spike', -0.3643964304627081),
#  ('offlin', -0.3623772907628341),
#  ('background', -0.3622614631951175),
#  ('regular', -0.36208141874188887),
#  ('trailer', -0.36187392570323107),
#  ('rip', -0.3617672159522076),
#  ('tast', -0.36067742749467063),
#  ('endless', -0.3591812111416796),
#  ('among', -0.3585275079987009),
#  ('bethesda', -0.35834868369421496),
#  ('pointless', -0.3566924222608502),
#  ('extrem', -0.35643400158804617),
#  ('dice', -0.35483359962691663),
#  ('sick', -0.354600026700585),
#  ('wasteland', -0.3543251581486684),
#  ('hell', -0.35396742175846246),
#  ('biom', -0.3535989974550992),
#  ('arcad', -0.3525118973321104),
#  ('speak', -0.35191354044921447),
#  ('slower', -0.3516660350363722),
#  ('address', -0.35157679457250396),
#  ('ammo', -0.3513204859599291),
#  ('red', -0.34975558244795646),
#  ('pw', -0.34829098221027327),
#  ('intend', -0.34773482039567616),
#  ('cubit', -0.34695233668561404),
#  ('versus', -0.34547645926757564),
#  ('il', -0.3450765568760011),
#  ('team', -0.3449540242584839),
#  ('within', -0.3445818672564512),
#  ('epic', -0.3443318378733315),
#  ('perman', -0.34300905781307817),
#  ('tini', -0.34159234503245073),
#  ('three', -0.3405474618673899),
#  ('defend', -0.340348025739303),
#  ('flux', -0.34027637966369284),
#  ('honest', -0.33927479662514176),
#  ('rocket', -0.33796285712556556),
#  ('higher', -0.33772962520025585),
#  ('campaign', -0.3363150641485808),
#  ('upgrad', -0.33622314439889034),
#  ('badg', -0.3359810142479112),
#  ('clue', -0.33597452747322354),
#  ('unlock', -0.3355909842781399),
#  ('vs', -0.33425356324781963),
#  ('und', -0.3326510060238949),
#  ('lv', -0.3320081327419834),
#  ('websit', -0.33062226964273367),
#  ('mg', -0.3298740325931052),
#  ('doubt', -0.32891473245714303),
#  ('beyond', -0.3284672425035856),
#  ('shift', -0.32836994561740634),
#  ('basi', -0.3267403415230897),
#  ('climb', -0.32619252770482854),
#  ('whatsoev', -0.3232156645576456),
#  ('threw', -0.32165742672716646),
#  ('spot', -0.32064575115138405),
#  ('wallet', -0.32056386858051406),
#  ('abil', -0.32051644381107086),
#  ('becasu', -0.3190068716943761),
#  ('classic', -0.3190014928868383),
#  ('menus', -0.3179911776551302),
#  ('sit', -0.3178410900434093),
#  ('inspir', -0.31783224373822844),
#  ('serious', -0.3171568338368983),
#  ('ez', -0.31525014180623256),
#  ('microtransact', -0.3151469134902819),
#  ('let', -0.31514634634253025),
#  ('recomend', -0.314307703417288),
#  ('ultim', -0.3138217839094245),
#  ('paywal', -0.31350904067919083),
#  ('tcg', -0.3134930772455762),
#  ('empti', -0.3130053998554071),
#  ('artwork', -0.3116357911537535),
#  ('environ', -0.3113099825077611),
#  ('tf', -0.31129929748514584),
#  ('profession', -0.311258553864454),
#  ('sent', -0.31087366090235147),
#  ('earth', -0.3107722995027686),
#  ('xp', -0.3105787375013915),
#  ('got', -0.30979232457292716),
#  ('orchestra', -0.3089579517193405),
#  ('bronz', -0.30884829960758786),
#  ('protect', -0.3084635285227249),
#  ('becous', -0.3083837563848483),
#  ('camo', -0.3083141592709203),
#  ('tire', -0.30698200617020294),
#  ('blast', -0.3057452730573507),
#  ('somehow', -0.3049923812392454),
#  ('sorri', -0.304602088989378),
#  ('quiet', -0.304588983248016),
#  ('present', -0.3045873117452095),
#  ('clan', -0.3031664323387739),
#  ('fail', -0.3021046192178974),
#  ('began', -0.3019266059786331),
#  ('account', -0.3013792341447927),
#  ('tweak', -0.3006815193709761),
#  ('built', -0.3006548752179672),
#  ('deep', -0.29999945098991276),
#  ('solut', -0.299574169170741),
#  ('lmgs', -0.2995604603585835),
#  ('reviewa', -0.2993077275125011),
#  ('flat', -0.29877480002678386),
#  ('four', -0.29846738952514523),
#  ('leav', -0.2982721223551583),
#  ('mass', -0.29550260200350886),
#  ('semi', -0.29312105114509446),
#  ('antitank', -0.29275522858994873),
#  ('modifi', -0.2926739393907509),
#  ('corner', -0.29116308341437264),
#  ('shark', -0.288865949554422),
#  ('infuri', -0.2861928075664506),
#  ('screenshot', -0.2847323487706952),
#  ('heal', -0.2839111609778147),
#  ('titl', -0.28387398041752393),
#  ('fest', -0.2824146378403103),
#  ('timer', -0.2814145972880471),
#  ('area', -0.2810417589333849),
#  ('meant', -0.2801610673612747),
#  ('se', -0.2799008581824181),
#  ('opportun', -0.2798249834862625),
#  ('cloud', -0.2791739798166379),
#  ('rp', -0.2784347243877531),
#  ('standalon', -0.2771053948482226),
#  ('collect', -0.2769521752171163),
#  ('phone', -0.2763438948546819),
#  ('neutral', -0.27569788494032976),
#  ('interest', -0.27519276210229854),
#  ('period', -0.2746398058810614),
#  ('core', -0.2725814054248541),
#  ('problem', -0.2721108369549562),
#  ('ride', -0.27173337917799767),
#  ('screen', -0.27086963438999806),
#  ('receiv', -0.27037825691713624),
#  ('feed', -0.270191999594414),
#  ('pass', -0.2697306354418026),
#  ('truck', -0.2693732338405986),
#  ('recal', -0.2686382843281478),
#  ('playerbas', -0.26820201849546466),
#  ('elsewher', -0.2678275783899171),
#  ('come', -0.26764655147859273),
#  ('american', -0.2653496025890905),
#  ('less', -0.2649589415555586),
#  ('often', -0.26486217115573196),
#  ('mustang', -0.2639634821142801),
#  ('smoke', -0.2635072916354783),
#  ('port', -0.262983227203026),
#  ('next', -0.2629745708994081),
#  ('disadvantag', -0.26132751031009016),
#  ('other', -0.2605826825006618),
#  ('mole', -0.25969992214254256),
#  ('diamond', -0.25883318288671475),
#  ('select', -0.2572015920885166),
#  ('sound', -0.256128175914086),
#  ('multipl', -0.25602329528880824),
#  ('accord', -0.25534322351974104),
#  ('kid', -0.25452507664933377),
#  ('phase', -0.2541595146772275),
#  ('around', -0.2539774391211683),
#  ('patienc', -0.2534605571599517),
#  ('tiger', -0.2531879798008405),
#  ('assault', -0.2522981087848941),
#  ('hot', -0.250766419072723),
#  ('deal', -0.2507590880810055),
#  ('remain', -0.25062838139907995),
#  ('union', -0.24886788138131324),
#  ('skin', -0.24789779896523323),
#  ('excus', -0.2477634767810229),
#  ('effect', -0.24750317736892985),
#  ('game', -0.24713254389078193),
#  ('sub', -0.2469989970604185),
#  ('dull', -0.2440049587432281),
#  ('deathclaw', -0.24362431423144898),
#  ('put', -0.2432940100557526),
#  ('uber', -0.24306751207394833),
#  ('ago', -0.2430114394386736),
#  ('global', -0.24300924016458436),
#  ('local', -0.24113379696818943),
#  ('full', -0.23988947766320726),
#  ('cute', -0.23959285144134743),
#  ('nonsens', -0.23940084719783492),
#  ('that', -0.23816218214197243),
#  ('anim', -0.23624681824696092),
#  ('ball', -0.23566622273445972),
#  ('newz', -0.23526775789859256),
#  ('gc', -0.23520229931569991),
#  ('hes', -0.2338407521188889),
#  ('stack', -0.23368834617851253),
#  ('former', -0.2328861996031183),
#  ('raid', -0.23202876104189035),
#  ('rich', -0.23188500390685257),
#  ('onto', -0.23158827445950164),
#  ('pilot', -0.23106272535003933),
#  ('entir', -0.23096993094336998),
#  ('book', -0.23033931948318612),
#  ('un', -0.23031761718028076),
#  ('aabout', -0.23001328457685674),
#  ('news', -0.2285658087767179),
#  ('jeep', -0.2284714636301604),
#  ('door', -0.2279817892130267),
#  ('oppon', -0.22785444175337313),
#  ('introduc', -0.2266857779088171),
#  ('consist', -0.22568188383116744),
#  ('compani', -0.22503584598006685),
#  ('hasnt', -0.22392632613185137),
#  ('freeplay', -0.22382875467411928),
#  ('mgs', -0.22090601923482123),
#  ('aggro', -0.22083461579405395),
#  ('expect', -0.21968695759067525),
#  ('almost', -0.21885767926662456),
#  ('buf', -0.21848397241723827),
#  ('rank', -0.2179368198423341),
#  ('bland', -0.21778485420710836),
#  ('rest', -0.21635112865835807),
#  ('recon', -0.21576582749062492),
#  ('si', -0.21573358902900505),
#  ('round', -0.21570153581842771),
#  ('skirmish', -0.21419189810492553),
#  ('somth', -0.21360644291671801),
#  ('remot', -0.21252318510889612),
#  ('answer', -0.2124164356400538),
#  ('general', -0.21182699266313249),
#  ('paint', -0.2115659086818491),
#  ('stuck', -0.21108459099239518),
#  ('bat', -0.2109669872542818),
#  ('foot', -0.21090850744762168),
#  ('cycl', -0.21063003576681777),
#  ('ok', -0.2089510704115308),
#  ('tedious', -0.20675506522065812),
#  ('damn', -0.20644360684694746),
#  ('unit', -0.20641974433458715),
#  ('men', -0.20625168239575437),
#  ('bolt', -0.2052643312016963),
#  ('comparison', -0.2050193198046447),
#  ('engag', -0.2041217636196087),
#  ('inventori', -0.2034681318450342),
#  ('storag', -0.20263401688454313),
#  ('troll', -0.20262173544988696),
#  ('prior', -0.20226468282446797),
#  ('feel', -0.20174119501053794),
#  ('bot', -0.2016205812831346),
#  ('hit', -0.19915863126685407),
#  ('hello', -0.1989707572338829),
#  ('perhap', -0.19870566255760408),
#  ('involv', -0.1984828887864244),
#  ('stale', -0.1968351379802133),
#  ('happi', -0.1967284388182743),
#  ('categori', -0.19622992999618893),
#  ('activ', -0.19605864494788783),
#  ('materi', -0.19476033075547963),
#  ('met', -0.19467027668563402),
#  ('space', -0.19366235794941764),
#  ('product', -0.18914511182838883),
#  ('machin', -0.18871310204048306),
#  ('biggest', -0.18844180464234078),
#  ('booster', -0.1883220520440585),
#  ('alright', -0.18828790041637303),
#  ('choic', -0.18754557522011828),
#  ('la', -0.1869829523686736),
#  ('replay', -0.18696919809037235),
#  ('mtg', -0.18653148190348684),
#  ('incid', -0.18645558984411625),
#  ('difficult', -0.1856709275870537),
#  ('paywin', -0.1852974053607311),
#  ('incom', -0.18439682864453733),
#  ('load', -0.18432627163714332),
#  ('dark', -0.18372709817216307),
#  ('standard', -0.1826598646386164),
#  ('dash', -0.18246699102525235),
#  ('manner', -0.1823327154039577),
#  ('youd', -0.1823108646349975),
#  ('mission', -0.18204815515949768),
#  ('normal', -0.18137981048878457),
#  ('oneshot', -0.1799524627172361),
#  ('headshot', -0.17963659432064089),
#  ('soon', -0.17866033118522556),
#  ('random', -0.17862630985248293),
#  ('tool', -0.17861307862479464),
#  ('immens', -0.17780933104080757),
#  ('larger', -0.17456400431243768),
#  ('creat', -0.1745043958749265),
#  ('reviewso', -0.1745036932392039),
#  ('sign', -0.17234954676781028),
#  ('capabl', -0.1722094240473437),
#  ('danger', -0.17038692770200486),
#  ('gunner', -0.16892341523380647),
#  ('alon', -0.16885635616033456),
#  ('middl', -0.16876207228247445),
#  ('th', -0.16863685693359512),
#  ('armour', -0.1670768284926173),
#  ('negat', -0.16670687026719666),
#  ('entertain', -0.16566130943103738),
#  ('respect', -0.16491317805892175),
#  ('ui', -0.16395176740129025),
#  ('usual', -0.16349185541060712),
#  ('brilliant', -0.1629835768149004),
#  ('anger', -0.1623932146786601),
#  ('lie', -0.16213351857189928),
#  ('buff', -0.1607662968836995),
#  ('safe', -0.16051275638819176),
#  ('actual', -0.16042470017323662),
#  ('roll', -0.16005221477224102),
#  ('ussr', -0.1594937351530488),
#  ('refund', -0.15913398246838142),
#  ('raider', -0.1583257980930068),
#  ('immedi', -0.15771077260299068),
#  ('werent', -0.1574989855503428),
#  ('submachin', -0.15727880570746205),
#  ('giant', -0.15714338369131559),
#  ('progress', -0.15600457076147628),
#  ('equip', -0.15585026389612813),
#  ('sens', -0.1550733904698685),
#  ('sluggish', -0.15424560560639963),
#  ('brand', -0.1526003917324502),
#  ('initi', -0.1520829774595443),
#  ('boom', -0.15207500547915465),
#  ('tho', -0.15198174709019152),
#  ('field', -0.15093959360603054),
#  ('agre', -0.15088222113582297),
#  ('twist', -0.14964366184758265),
#  ('bias', -0.14895439664898477),
#  ('alli', -0.14726333624097057),
#  ('succeed', -0.146811935973151),
#  ('number', -0.14364615607913636),
#  ('profit', -0.14329392566213078),
#  ('masteri', -0.14009663843347375),
#  ('trial', -0.1394237735202351),
#  ('order', -0.1384569178655757),
#  ('ticket', -0.1362106879949592),
#  ('currenc', -0.13522374200390114),
#  ('physic', -0.135061087022393),
#  ('respond', -0.1341212902693613),
#  ('never', -0.13288861485748854),
#  ('ii', -0.13199337027366226),
#  ('threat', -0.13173831786981074),
#  ('came', -0.13107830539171456),
#  ('boot', -0.13089128514594153),
#  ('airplan', -0.12985474520480944),
#  ('reciev', -0.12953862611869177),
#  ('thought', -0.12910171894309047),
#  ('voic', -0.12863030397633668),
#  ('simmer', -0.1286106665274162),
#  ('default', -0.12841404466227718),
#  ('base', -0.12793201762590167),
#  ('welcom', -0.12702957236120802),
#  ('generat', -0.12617995182108208),
#  ('recoil', -0.12590646733695118),
#  ('prone', -0.12552932897563335),
#  ('industri', -0.12535408825213967),
#  ('spell', -0.12534644283426136),
#  ('parti', -0.12448450665028801),
#  ('plot', -0.12370363700842915),
#  ('ran', -0.1236638498792112),
#  ('glitchi', -0.12355894874663798),
#  ('purpl', -0.12254329118164048),
#  ('month', -0.12205609110895978),
#  ('busi', -0.12167867499727046),
#  ('polish', -0.12128369467507011),
#  ('smart', -0.12071979380605848),
#  ('pack', -0.12047570603011071),
#  ('scratch', -0.12019385336876783),
#  ('green', -0.11966741810968942),
#  ('five', -0.11916732555836157),
#  ('minim', -0.11891608209420744),
#  ('theme', -0.11553123099793447),
#  ('tech', -0.11528240970911705),
#  ('section', -0.11434369764700465),
#  ('android', -0.11347709835892489),
#  ('freetoplay', -0.11263024895931889),
#  ('victori', -0.11124645095546748),
#  ('premium', -0.11069435297986108),
#  ('studio', -0.10996223549449893),
#  ('smgs', -0.10863837086669373),
#  ('caus', -0.10846080289053195),
#  ('feet', -0.10752406692878466),
#  ('tbh', -0.10672745795261707),
#  ('reccommend', -0.10661850559521993),
#  ('reset', -0.10642959312660039),
#  ('creation', -0.10523512577731474),
#  ('app', -0.10473405442069482),
#  ('surfac', -0.10462109873301156),
#  ('superior', -0.1044206427605548),
#  ('gtx', -0.102586089526882),
#  ('odd', -0.1022687591282122),
#  ('realiti', -0.10211798575998773),
#  ('salt', -0.10125098171648975),
#  ('strength', -0.10065433206243123),
#  ('modern', -0.1001934943508702)]

# %%
sorted(neg_.items(),reverse=True ,key=operator.itemgetter(1))
# Out:
# [('addict', 2.7538475129732296),
#  ('best', 2.6355636858686977),
#  ('smash', 2.5776833376078265),
#  ('great', 2.5077551868561736),
#  ('dungeon', 2.477267923865855),
#  ('amaz', 2.3324905040162447),
#  ('charact', 2.33143850474479),
#  ('learn', 2.0684021755693114),
#  ('simul', 2.0352944424991444),
#  ('fun', 2.0336269358483214),
#  ('bit', 2.009023225214053),
#  ('easi', 2.005008078942649),
#  ('elsword', 1.922125741319682),
#  ('complain', 1.8445094273956606),
#  ('job', 1.7567829414039995),
#  ('rotmg', 1.7410212925660185),
#  ('improv', 1.7324394026742025),
#  ('awesom', 1.6796666449253714),
#  ('fantast', 1.6524269243398537),
#  ('perfect', 1.638396778818709),
#  ('style', 1.6323992462591916),
#  ('say', 1.6192924677817586),
#  ('easier', 1.5828507569616277),
#  ('bros', 1.5750734291327537),
#  ('overal', 1.5400603360366674),
#  ('life', 1.5159253593816289),
#  ('lane', 1.5117017518845484),
#  ('elder', 1.4814613019794838),
#  ('trade', 1.475583805058011),
#  ('item', 1.454614266921168),
#  ('freedom', 1.4462797788516069),
#  ('good', 1.38423255238895),
#  ('gear', 1.3723503171033498),
#  ('competit', 1.3597138960657846),
#  ('soul', 1.3577519054741476),
#  ('zen', 1.3406597509887537),
#  ('mount', 1.3369586455929805),
#  ('solid', 1.3217991642946365),
#  ('definit', 1.3038061927354134),
#  ('costum', 1.2794742254696032),
#  ('switch', 1.274779497042547),
#  ('pace', 1.2631707509460481),
#  ('there', 1.260031860699545),
#  ('tier', 1.2595327959561962),
#  ('wot', 1.2498942757904807),
#  ('spare', 1.245415232307209),
#  ('love', 1.2339323049599147),
#  ('definat', 1.2265193850527953),
#  ('mmo', 1.2249138416679173),
#  ('neverwint', 1.197653096643906),
#  ('world', 1.1969708607309122),
#  ('dd', 1.1831019062517079),
#  ('fli', 1.1825831790820533),
#  ('pvp', 1.1757927994345465),
#  ('favorit', 1.1749887108482344),
#  ('person', 1.1734894409898884),
#  ('hurt', 1.1713911678589313),
#  ('deca', 1.16956671560747),
#  ('mmorpg', 1.1592568903034075),
#  ('alot', 1.1490328823521145),
#  ('scroll', 1.1386689413963682),
#  ('score', 1.1327895430225359),
#  ('land', 1.1319114007117328),
#  ('larg', 1.1272463131421002),
#  ('con', 1.1219498512034334),
#  ('downsid', 1.11038857063852),
#  ('along', 1.1096359619109957),
#  ('flash', 1.104310201599042),
#  ('teleport', 1.1034504743533113),
#  ('quit', 1.1028157377998362),
#  ('rune', 1.0963403788644897),
#  ('sut', 1.0889501677562512),
#  ('legend', 1.085362989735813),
#  ('action', 1.0850865200045279),
#  ('enjoy', 1.0826499121489186),
#  ('though', 1.0812076690586083),
#  ('complaint', 1.0811772872908798),
#  ('queue', 1.0706840664184016),
#  ('hardest', 1.0648528917913607),
#  ('hors', 1.0578385050881467),
#  ('cod', 1.054684412047944),
#  ('twitch', 1.047883984138023),
#  ('chicken', 1.0474144937025047),
#  ('press', 1.043287471236734),
#  ('viabl', 1.0427349898854485),
#  ('guild', 1.0282907234417182),
#  ('ever', 1.024559969272408),
#  ('mammoth', 1.021393213852131),
#  ('brawlhalla', 1.0051516765478994),
#  ('attackforwardstrong', 1.0),
#  ('carri', 0.9900103720124784),
#  ('sim', 0.9874110776772609),
#  ('mm', 0.9856799582324913),
#  ('practic', 0.9808118146088584),
#  ('nowaday', 0.9801144340885088),
#  ('potato', 0.9795415580411715),
#  ('excit', 0.974017067182152),
#  ('realli', 0.9639049212315874),
#  ('pleas', 0.9600962573495695),
#  ('chill', 0.9583709497544773),
#  ('friend', 0.9572304088988841),
#  ('self', 0.9550512987450811),
#  ('reviewgreat', 0.9491403842336595),
#  ('digit', 0.9359675535167538),
#  ('yet', 0.9358458355832656),
#  ('smooth', 0.9313711384679869),
#  ('combat', 0.9302073481612841),
#  ('add', 0.9283643038589335),
#  ('truli', 0.9260329808561877),
#  ('flight', 0.9176407006913864),
#  ('littl', 0.9140265964753362),
#  ('youtub', 0.9134613241269401),
#  ('cubeworld', 0.9128856765697594),
#  ('like', 0.912765580401095),
#  ('pet', 0.9121441572162126),
#  ('pant', 0.9109875007457918),
#  ('platform', 0.909465868925472),
#  ('encount', 0.9062728392150038),
#  ('type', 0.9035559509920209),
#  ('act', 0.9010887554241065),
#  ('singleplay', 0.895473753489353),
#  ('ccg', 0.8949314183171613),
#  ('also', 0.8912241634206859),
#  ('skyrim', 0.888466255247131),
#  ('rememb', 0.8830262056506415),
#  ('sometim', 0.8800065288912339),
#  ('regist', 0.8798257464734653),
#  ('realm', 0.875897673249463),
#  ('whenev', 0.8745602342568624),
#  ('fair', 0.8674521766833476),
#  ('em', 0.8658234105907832),
#  ('hang', 0.8601856471173168),
#  ('cours', 0.8561388544101285),
#  ('still', 0.8512350173454188),
#  ('muchi', 0.8511392493011927),
#  ('high', 0.8509156939053572),
#  ('soldier', 0.8485009329928619),
#  ('depend', 0.83770377465082),
#  ('awsom', 0.8316265658375073),
#  ('hota', 0.8312823854321774),
#  ('consid', 0.8267336567638959),
#  ('content', 0.8245493341124132),
#  ('definet', 0.8242918340322776),
#  ('battlefield', 0.8203799080362537),
#  ('window', 0.8196239602060844),
#  ('kabam', 0.8194487595354214),
#  ('nice', 0.8181076374640743),
#  ('rang', 0.8144047114319755),
#  ('slot', 0.8083771260323807),
#  ('somewhat', 0.807214168033543),
#  ('school', 0.8070697856605984),
#  ('dnd', 0.8036963857838472),
#  ('write', 0.8028753569213881),
#  ('joystick', 0.8003676294806414),
#  ('lag', 0.7998888278217642),
#  ('mmos', 0.7995227648688703),
#  ('figur', 0.7990791048318128),
#  ('ive', 0.79863183406236),
#  ('event', 0.7978918337039232),
#  ('reviewbrawlhalla', 0.7975374352283263),
#  ('master', 0.7946825786327529),
#  ('surpris', 0.7927557665364107),
#  ('fight', 0.7911934399238968),
#  ('missil', 0.7911155409049295),
#  ('club', 0.7838205009246171),
#  ('hardcor', 0.7818318075126364),
#  ('coin', 0.7812991597844205),
#  ('mix', 0.7775259886774563),
#  ('teach', 0.7770369708929225),
#  ('ppl', 0.776873512358921),
#  ('dislik', 0.7768014782208915),
#  ('heartston', 0.776017747250896),
#  ('client', 0.7756686759195104),
#  ('skill', 0.770528289235046),
#  ('word', 0.7670260935731119),
#  ('hearthston', 0.7658842880376392),
#  ('luckili', 0.7649174414899484),
#  ('tactic', 0.7622881752923725),
#  ('easili', 0.7572949059255023),
#  ('dive', 0.7572747352312146),
#  ('plan', 0.756846505868115),
#  ('well', 0.752869676596005),
#  ('equal', 0.7515608990663825),
#  ('up', 0.7514411316864291),
#  ('huge', 0.7501086288286289),
#  ('home', 0.7479524238484316),
#  ('ara', 0.7478784542521624),
#  ('bonus', 0.7456460461835579),
#  ('affect', 0.7453549898141769),
#  ('editor', 0.7429034381462698),
#  ('call', 0.7425102681568154),
#  ('quest', 0.7419263561662159),
#  ('gamer', 0.7398044557798086),
#  ('enough', 0.737725108846673),
#  ('kog', 0.7351447151418204),
#  ('wwii', 0.7296763414165179),
#  ('plane', 0.7295226685558901),
#  ('repetit', 0.7294427860998616),
#  ('realist', 0.7290898377649828),
#  ('rpg', 0.7268776339064283),
#  ('quicker', 0.725625171259255),
#  ('steam', 0.7254631337049242),
#  ('current', 0.7231157636085073),
#  ('mig', 0.7220670419472359),
#  ('light', 0.7215896522203282),
#  ('earn', 0.7204222356313467),
#  ('peopl', 0.7193531670545599),
#  ('obvious', 0.7189088755374466),
#  ('rock', 0.7184614909593465),
#  ('reviewif', 0.7165097031532075),
#  ('hous', 0.7154993332949429),
#  ('killer', 0.7138909509508653),
#  ('decent', 0.7134223232384389),
#  ('onlin', 0.7128720887381618),
#  ('patient', 0.7090512404233029),
#  ('much', 0.7025446566505491),
#  ('non', 0.7010635353129082),
#  ('rage', 0.6968927232186312),
#  ('waster', 0.695764411290597),
#  ('fan', 0.6955732275029605),
#  ('hammer', 0.692184763329178),
#  ('arena', 0.691267561568938),
#  ('mad', 0.6878985840022962),
#  ('carrier', 0.6872848713835974),
#  ('outstand', 0.687055537618196),
#  ('voxel', 0.6863990401983915),
#  ('ps', 0.6853130648452203),
#  ('speed', 0.6837352882268036),
#  ('provid', 0.6778277634638992),
#  ('playabl', 0.6732571775344284),
#  ('right', 0.672280384828703),
#  ('plenti', 0.6719928129261957),
#  ('apart', 0.6713492018063734),
#  ('hard', 0.667264215592368),
#  ('bunch', 0.6672455416932854),
#  ('recommend', 0.66614624161826),
#  ('fc', 0.6622660851925373),
#  ('tell', 0.6620783775521748),
#  ('technic', 0.6612237799093762),
#  ('free', 0.6599975513349488),
#  ('beauti', 0.647515657432376),
#  ('profil', 0.6462569743218909),
#  ('color', 0.6447863350238738),
#  ('sale', 0.6442355784764074),
#  ('big', 0.6436479067972849),
#  ('key', 0.6415826691193013),
#  ('note', 0.641362316731738),
#  ('hate', 0.640273852879048),
#  ('watch', 0.6380690146510166),
#  ('everybodi', 0.6379103347477499),
#  ('unlik', 0.6375063432309154),
#  ('hold', 0.6356191357673275),
#  ('steep', 0.6274244552565343),
#  ('necessari', 0.6228257486229907),
#  ('rpgs', 0.6209777239908398),
#  ('weird', 0.6202530035798175),
#  ('combin', 0.6178489351089294),
#  ('simpl', 0.6156087654452069),
#  ('heavili', 0.6153710621947535),
#  ('playstyl', 0.6141044510097251),
#  ('throttl', 0.6133962184122683),
#  ('manual', 0.6133535709287391),
#  ('uniqu', 0.6099158700568897),
#  ('choos', 0.609709695444464),
#  ('favourit', 0.6088728825236424),
#  ('addit', 0.6077950369186917),
#  ('generous', 0.6049511250771057),
#  ('satisfi', 0.6033352915329858),
#  ('appli', 0.6018857556647863),
#  ('half', 0.6003016788199008),
#  ('dcs', 0.598852339418625),
#  ('noob', 0.5985179013321975),
#  ('run', 0.5963238050774665),
#  ('close', 0.5951533622825376),
#  ('weekend', 0.5940661732811497),
#  ('pictur', 0.5914315117070721),
#  ('pretti', 0.5890361628382307),
#  ('guard', 0.5873054264754806),
#  ('help', 0.5843952544319231),
#  ('resolut', 0.5842388052445625),
#  ('perform', 0.5830248982026089),
#  ('pokemon', 0.5827802149245014),
#  ('salti', 0.582769766322121),
#  ('hope', 0.582623514758308),
#  ('focus', 0.5825424269222614),
#  ('first', 0.5819601851952452),
#  ('recent', 0.5818750432410106),
#  ('tablet', 0.5788702760778777),
#  ('librari', 0.578347541198044),
#  ('whether', 0.5769573638064973),
#  ('summer', 0.576640117031308),
#  ('faster', 0.5765192024154063),
#  ('familiar', 0.5735992691252039),
#  ('version', 0.5728108055460978),
#  ('must', 0.5727395507971682),
#  ('beat', 0.5694646457500874),
#  ('would', 0.5687561156294454),
#  ('wargam', 0.5669092674381827),
#  ('brawl', 0.5666181814737488),
#  ('difficulti', 0.5659533211868932),
#  ('challeng', 0.5645418497527631),
#  ('neat', 0.562764401265367),
#  ('esl', 0.5622786550123382),
#  ('boss', 0.5604724958902332),
#  ('popular', 0.5602727003581993),
#  ('advantag', 0.5597843551567734),
#  ('especi', 0.5591424764441535),
#  ('market', 0.5591327648645695),
#  ('fp', 0.5551592883719653),
#  ('comment', 0.5542696187355767),
#  ('lot', 0.5519905130040786),
#  ('breath', 0.5513919293753575),
#  ('complic', 0.5505533600503716),
#  ('ton', 0.5496206207814563),
#  ('certain', 0.5485189501144168),
#  ('ignor', 0.5480427784728438),
#  ('shell', 0.5456810150954522),
#  ('exchang', 0.5426976782999283),
#  ('owner', 0.5400258018620914),
#  ('varieti', 0.5399333232015051),
#  ('combo', 0.5391322181456536),
#  ('pve', 0.5390256280347121),
#  ('havent', 0.5377369135271862),
#  ('ahead', 0.5368360977183866),
#  ('hp', 0.5365206594884266),
#  ('devic', 0.5365020015299979),
#  ('su', 0.5363907783186282),
#  ('medium', 0.5347398526457734),
#  ('nostalgia', 0.533750785103385),
#  ('avatar', 0.5335399383444775),
#  ('stone', 0.5335326102369893),
#  ('intens', 0.533367374754659),
#  ('earli', 0.533321011596834),
#  ('stage', 0.5311937666953133),
#  ('boost', 0.5300829237291231),
#  ('keyboard', 0.5280721970532432),
#  ('public', 0.5278329799623916),
#  ('howev', 0.5257325337223265),
#  ('gamei', 0.5253055875268172),
#  ('dlcs', 0.5249422389245036),
#  ('de', 0.5245874379337624),
#  ('ingam', 0.5238112950688598),
#  ('bottom', 0.5229171319841764),
#  ('play', 0.5219816360896539),
#  ('split', 0.5208225930867207),
#  ('vr', 0.5196195303836663),
#  ('knew', 0.5189113936257028),
#  ('genr', 0.5187035199041797),
#  ('brawler', 0.518407087943527),
#  ('invest', 0.5175694857234616),
#  ('abl', 0.5172742833992259),
#  ('japanes', 0.516957089108239),
#  ('stock', 0.5169083527917958),
#  ('radar', 0.515748608669557),
#  ('code', 0.515481005794397),
#  ('etc', 0.5137125052549506),
#  ('bank', 0.5132431282116007),
#  ('strategi', 0.5123364658788924),
#  ('lore', 0.5118820640329164),
#  ('guid', 0.5104134713761732),
#  ('alway', 0.5052674635986124),
#  ('di', 0.5052528965862249),
#  ('contact', 0.5027555954401074),
#  ('warn', 0.5014586660104168),
#  ('hardwar', 0.501276320171872),
#  ('demand', 0.5002539064423108),
#  ('itth', 0.4975182618457361),
#  ('tes', 0.4962108370613096),
#  ('shadow', 0.4961366162390948),
#  ('eventu', 0.49091377168545886),
#  ('defens', 0.49026470649474535),
#  ('hidden', 0.48986607703517926),
#  ('wonder', 0.4894721990780542),
#  ('find', 0.487377290785591),
#  ('said', 0.48618933379861884),
#  ('everyon', 0.4858212438806898),
#  ('seen', 0.4843170840886878),
#  ('latenc', 0.48194980282565414),
#  ('grasp', 0.48143298919776695),
#  ('daili', 0.4786951115125244),
#  ('gather', 0.4763632749649204),
#  ('usa', 0.47611656405509817),
#  ('later', 0.4745048610218505),
#  ('shop', 0.47369163822052623),
#  ('result', 0.4734286010751123),
#  ('dream', 0.47224489725945973),
#  ('steal', 0.47194249087462625),
#  ('freeli', 0.4707226958149988),
#  ('brother', 0.47002896453532544),
#  ('citi', 0.4669082541558861),
#  ('bc', 0.4664017537333889),
#  ('reward', 0.46599455678298946),
#  ('advanc', 0.4655085523452227),
#  ('hs', 0.46547935465292384),
#  ('ice', 0.4649801223129789),
#  ('trove', 0.4638082323457113),
#  ('pick', 0.46134631970709716),
#  ('chosen', 0.46117666951373304),
#  ('opinion', 0.4592505393205373),
#  ('real', 0.4574208974461863),
#  ('understand', 0.45734194621905044),
#  ('thank', 0.4568157539512862),
#  ('check', 0.45612402907482824),
#  ('one', 0.45236999622183216),
#  ('worthi', 0.4519240748030031),
#  ('monster', 0.45099430553864),
#  ('subscript', 0.4507665792173097),
#  ('get', 0.44895420017389837),
#  ('simpler', 0.44804300339118774),
#  ('jump', 0.4477867326576343),
#  ('instanc', 0.4456449355118951),
#  ('purchas', 0.4450445936613049),
#  ('need', 0.4450327117152538),
#  ('concern', 0.4430876906352788),
#  ('stori', 0.44166580734376426),
#  ('arti', 0.4407930695583744),
#  ('lvl', 0.4406094745179152),
#  ('see', 0.43535380652570255),
#  ('aircraft', 0.4352143276008222),
#  ('stun', 0.43435274383461675),
#  ('kching', 0.43412916625475406),
#  ('mine', 0.4332598329387027),
#  ('launcher', 0.43153002138835506),
#  ('variant', 0.42684341582004204),
#  ('prepar', 0.4258888057302511),
#  ('veteran', 0.4257654455975688),
#  ('side', 0.42481666739131724),
#  ('quick', 0.4242860221869026),
#  ('bike', 0.42271950672035974),
#  ('previous', 0.42246072087109265),
#  ('decid', 0.422089928334878),
#  ('profess', 0.4218170267762047),
#  ('ac', 0.4192592815818883),
#  ('cheap', 0.4172922705416487),
#  ('although', 0.41710563731884687),
#  ('chest', 0.4165895300966127),
#  ('synergi', 0.4153444847972566),
#  ('your', 0.41461059954146084),
#  ('altern', 0.4143764641227085),
#  ('anyway', 0.4135236640737141),
#  ('listen', 0.4126667540693568),
#  ('flame', 0.4123702809520932),
#  ('spec', 0.41095352801380314),
#  ('laptop', 0.4102293575870155),
#  ('without', 0.40875739658710186),
#  ('chung', 0.40839988790418785),
#  ('accept', 0.40760010568757926),
#  ('requir', 0.405149153109073),
#  ('mechan', 0.40447799099925835),
#  ('sake', 0.4043436340718356),
#  ('retro', 0.4042232165113521),
#  ('fire', 0.40415258528112263),
#  ('model', 0.4036663729332969),
#  ('spammer', 0.40215583933431254),
#  ('damag', 0.4011251629849908),
#  ('travel', 0.40068094304358803),
#  ('fresh', 0.40037671629694277),
#  ('channel', 0.3990512593756893),
#  ('terrain', 0.3990006355468614),
#  ('mistak', 0.3987562116757818),
#  ('mele', 0.3985423318883337),
#  ('accomplish', 0.3976657051500654),
#  ('break', 0.3963602220312924),
#  ('thorough', 0.39475743503262506),
#  ('fool', 0.3939871706509629),
#  ('excel', 0.3920184719641712),
#  ('level', 0.3916517046069658),
#  ('touch', 0.39073160044077543),
#  ('layout', 0.3904088914427149),
#  ('startup', 0.3900272128607006),
#  ('implement', 0.38987161591190495),
#  ('foundri', 0.38955830320511875),
#  ('question', 0.38903524244601506),
#  ('kv', 0.3880968335593337),
#  ('kinda', 0.3875717785509837),
#  ('vet', 0.38742045934360336),
#  ('forward', 0.38735767646018265),
#  ('cross', 0.38667356998597263),
#  ('town', 0.3865779324565195),
#  ('control', 0.3857454467148245),
#  ('probabl', 0.3853234939564607),
#  ('solo', 0.38531835287641897),
#  ('gwent', 0.3852642984384862),
#  ('modif', 0.38345020461886853),
#  ('night', 0.3833970760511948),
#  ('somebodi', 0.3829415818075468),
#  ('featur', 0.3801358440321752),
#  ('armi', 0.3771026384797446),
#  ('timei', 0.3763424014526476),
#  ('vive', 0.3763358277752963),
#  ('work', 0.37574188428199146),
#  ('wow', 0.37535160074831825),
#  ('nois', 0.37523553674102406),
#  ('visual', 0.37448520569720695),
#  ('ect', 0.3732310143833),
#  ('similar', 0.3729754268412263),
#  ('region', 0.372650923386591),
#  ('thousand', 0.3711010733149948),
#  ('cup', 0.37099411644317737),
#  ('heard', 0.37077752340333453),
#  ('ghz', 0.37014075956485454),
#  ('size', 0.36999945677063284),
#  ('hey', 0.3687530279712382),
#  ('main', 0.3685228079765608),
#  ('dedic', 0.3681824695170623),
#  ('iv', 0.36670222779327544),
#  ('jet', 0.3639526226783958),
#  ('suggest', 0.3633806434551823),
#  ('term', 0.36329095718141935),
#  ('method', 0.3622160652143215),
#  ('spread', 0.3610819602962516),
#  ('heck', 0.36061077321278545),
#  ('cough', 0.35955253739484755),
#  ('elf', 0.35905043087210403),
#  ('link', 0.3589568173587191),
#  ('massiv', 0.3582194503616023),
#  ('discov', 0.35806050979870563),
#  ('open', 0.3569624047456696),
#  ('task', 0.3568344635116415),
#  ('curv', 0.35659622351792825),
#  ('hire', 0.35430407374746076),
#  ('joy', 0.3541320181874373),
#  ('attent', 0.35391299606910187),
#  ('import', 0.35388533261563293),
#  ('happen', 0.35200415281541114),
#  ('relat', 0.34945334206162826),
#  ('fulli', 0.3493770543052696),
#  ('option', 0.3487407121820487),
#  ('son', 0.34854032976450855),
#  ('read', 0.34815412639810595),
#  ('overhaul', 0.34690454092915035),
#  ('ah', 0.3469019266826924),
#  ('saw', 0.3468893839709821),
#  ('return', 0.3464102779058654),
#  ('miss', 0.34564854849591825),
#  ('dire', 0.34551680177599975),
#  ('special', 0.34318297626947414),
#  ('memori', 0.34314817633736194),
#  ('cent', 0.3429896135086451),
#  ('chao', 0.3426688523135871),
#  ('straight', 0.3423608951143622),
#  ('walk', 0.34207118029230604),
#  ('mous', 0.3405731111441693),
#  ('soviet', 0.33963461466387973),
#  ('forget', 0.33700334597748866),
#  ('fine', 0.33654480613504845),
#  ('hand', 0.3352592575688751),
#  ('dosnt', 0.3337292452792218),
#  ('craft', 0.3334606561407448),
#  ('retomoto', 0.33179636317159455),
#  ('worth', 0.33173417776584035),
#  ('csgo', 0.33142058435526045),
#  ('format', 0.33083303795972274),
#  ('amount', 0.33022693545833715),
#  ('soundtrack', 0.33018579340472076),
#  ('ptw', 0.32992409427651864),
#  ('tab', 0.3279547542342605),
#  ('worri', 0.32651797095036705),
#  ('warcraft', 0.32649519167753766),
#  ('young', 0.3262863141691684),
#  ('depth', 0.32613896800839665),
#  ('necessarili', 0.324902512602222),
#  ('fantasi', 0.32408069376479076),
#  ('found', 0.3237555658070124),
#  ('regard', 0.32217428456161046),
#  ('dime', 0.3215205643948699),
#  ('usd', 0.3213609870414626),
#  ('floor', 0.3198413064939733),
#  ('hat', 0.31918860605619537),
#  ('group', 0.3187545277887919),
#  ('click', 0.3186197975178333),
#  ('fish', 0.31841130287367936),
#  ('browser', 0.31827475045842835),
#  ('funni', 0.31805503903086435),
#  ('tend', 0.3129269066406932),
#  ('cliff', 0.3126711272853771),
#  ('today', 0.3123038463068099),
#  ('casual', 0.31153682852318687),
#  ('horrend', 0.31111442553282576),
#  ('may', 0.31076355044037113),
#  ('differ', 0.30920979448073965),
#  ('case', 0.30848452823089567),
#  ('most', 0.30774287136059547),
#  ('annoy', 0.3067269055501182),
#  ('influenc', 0.3063370069705512),
#  ('rogu', 0.305049355590697),
#  ('laggi', 0.3046426626333475),
#  ('grand', 0.30462930082445866),
#  ('take', 0.3036724277150591),
#  ('signific', 0.3015323741835951),
#  ('cool', 0.30139191576597596),
#  ('permadeath', 0.29876944386245596),
#  ('bought', 0.2974530079373842),
#  ('line', 0.29719725881311787),
#  ('small', 0.2965115007047197),
#  ('sinc', 0.29546791987503906),
#  ('join', 0.29430314547302266),
#  ('complex', 0.2941839321834356),
#  ('vip', 0.29377547047819336),
#  ('artilleri', 0.29335856665669713),
#  ('magic', 0.29184952132678355),
#  ('consol', 0.29146462469471557),
#  ('button', 0.29012612027810136),
#  ('review', 0.2887182175806433),
#  ('closer', 0.28854061513944484),
#  ('heart', 0.2881457698066423),
#  ('youv', 0.2878642985310475),
#  ('done', 0.2867632551647035),
#  ('togeth', 0.2858230083089271),
#  ('bf', 0.2852943252074077),
#  ('consum', 0.2851580357716807),
#  ('therefor', 0.2850927464459),
#  ('shouldnt', 0.282810318943653),
#  ('bound', 0.2827798667661027),
#  ('atroci', 0.2826349335224874),
#  ('believ', 0.2812373075009851),
#  ('fighter', 0.2807454742880834),
#  ('reviewfirst', 0.27917604420007436),
#  ('immers', 0.27906483409759236),
#  ('think', 0.27873385639729115),
#  ('astral', 0.277426945237087),
#  ('detail', 0.27692994666782633),
#  ('wotb', 0.27676919565005087),
#  ('lover', 0.27613075924881064),
#  ('fluid', 0.2760211629880723),
#  ('troubl', 0.27535146011737605),
#  ('superb', 0.2753285926364909),
#  ('appreci', 0.2747207583458765),
#  ('bar', 0.2745326369909417),
#  ('tough', 0.27433463338584135),
#  ('pcs', 0.2722739560333229),
#  ('youll', 0.2720923417785768),
#  ('rli', 0.27064812731826626),
#  ('delay', 0.2699662593544818),
#  ('cosmet', 0.26794444273224544),
#  ('countri', 0.2664819127651942),
#  ('yes', 0.2660109548557732),
#  ('isnt', 0.26478082240896483),
#  ('rig', 0.2644359776753229),
#  ('stabl', 0.26380169846866475),
#  ('shooter', 0.26268578764769707),
#  ('teamwork', 0.2621056845448593),
#  ('british', 0.261088195318483),
#  ('dodg', 0.261058642899337),
#  ('generic', 0.260239962371829),
#  ('militari', 0.26005907357879077),
#  ('adventur', 0.25974363669368183),
#  ('faction', 0.2594694156465953),
#  ('setup', 0.25889313956480176),
#  ('object', 0.2584334940617385),
#  ('chose', 0.258072364346595),
#  ('white', 0.2577785695878097),
#  ('attribut', 0.25719185346194695),
#  ('drag', 0.2571681988030816),
#  ('over', 0.25712097875449735),
#  ('remind', 0.25571337217716567),
#  ('reallif', 0.2553131184628163),
#  ('excess', 0.2546226873508482),
#  ('upon', 0.2542840967801785),
#  ('aswel', 0.25293287040398343),
#  ('wear', 0.25256034306280123),
#  ('addon', 0.25143844478774274),
#  ('armor', 0.24952366703249068),
#  ('perk', 0.24867587675479516),
#  ('exist', 0.24866792396357454),
#  ('pull', 0.24745524709802563),
#  ('social', 0.24743571703466213),
#  ('stick', 0.24715196912015414),
#  ('english', 0.24644588970290215),
#  ('man', 0.2459241968786251),
#  ('race', 0.24587014777873872),
#  ('origin', 0.24576398901457455),
#  ('rekt', 0.24564150211545122),
#  ('seat', 0.2455319625966262),
#  ('minor', 0.24547728591922338),
#  ('per', 0.24540037218775387),
#  ('fault', 0.2447408844197697),
#  ('masterpiec', 0.24271225545859842),
#  ('mate', 0.24257721387388667),
#  ('thrustmast', 0.24233696722219816),
#  ('freak', 0.24145644832266985),
#  ('leader', 0.24071301495805347),
#  ('trackir', 0.23846139099676575),
#  ('tank', 0.23827434982739873),
#  ('regret', 0.23743308183096687),
#  ('streamer', 0.23710880819367025),
#  ('element', 0.2363480520812753),
#  ('video', 0.23561324419064505),
#  ('aviat', 0.23396822171118994),
#  ('mother', 0.2338787841238371),
#  ('warthog', 0.23366822388064276),
#  ('specif', 0.23263049894179383),
#  ('privat', 0.23036880622423436),
#  ('oper', 0.23015341162155856),
#  ('numer', 0.22948934076258365),
#  ('grey', 0.2293191840094535),
#  ('ninja', 0.22906143162926668),
#  ('dragon', 0.2290295042334033),
#  ('simplifi', 0.2287146356119248),
#  ('knowledg', 0.2285939722448237),
#  ('starter', 0.22845103177915996),
#  ('clean', 0.22559454084290284),
#  ('nation', 0.22497462934321466),
#  ('avail', 0.22467877727442281),
#  ('prove', 0.22319860266143524),
#  ('ring', 0.22307448063938898),
#  ('harder', 0.22298639269601833),
#  ('afk', 0.22174400719575826),
#  ('garand', 0.22116609345796484),
#  ('far', 0.22001426702692967),
#  ('thier', 0.21736664419538138),
#  ('shown', 0.21704832678308483),
#  ('introduct', 0.2154655379968783),
#  ('rift', 0.21487782425575203),
#  ('lower', 0.21441455387260624),
#  ('toward', 0.21438422165377732),
#  ('prefer', 0.21423963177986244),
#  ('upset', 0.21406647301220913),
#  ('everyday', 0.21392856552510064),
#  ('primari', 0.21380189385170212),
#  ('guess', 0.21288384964599552),
#  ('huey', 0.2127567956876257),
#  ('particular', 0.2122430972399929),
#  ('true', 0.21087305507457585),
#  ('maximum', 0.210830303307375),
#  ('legit', 0.21054616487499753),
#  ('tabl', 0.21038797427220385),
#  ('day', 0.20993482529369262),
#  ('exploit', 0.20977721535837401),
#  ('hud', 0.20922313530615094),
#  ('seek', 0.20782322013879645),
#  ('zone', 0.20726733054169),
#  ('internet', 0.2067093710741421),
#  ('im', 0.20670629491325992),
#  ('xd', 0.2065934404327811),
#  ('helicopt', 0.20606031807333855),
#  ('beta', 0.20473174881363265),
#  ('clear', 0.2029569562161955),
#  ('messag', 0.20246623624497256),
#  ('extent', 0.2019603862745108),
#  ('offer', 0.20193897475460962),
#  ('procedur', 0.2014741861155512),
#  ('diffrent', 0.20112990284023263),
#  ('sweet', 0.20054736253625488),
#  ('slowli', 0.20021227674962397),
#  ('wolf', 0.1985252351517891),
#  ('mark', 0.19795903866669307),
#  ('million', 0.19658377672203986),
#  ('thing', 0.1962103823597236),
#  ('realism', 0.19615041139191625),
#  ('morrowind', 0.19558938307805662),
#  ('inde', 0.19485172125106348),
#  ('heavi', 0.19396701233571823),
#  ('oculus', 0.19352841524777414),
#  ('respons', 0.19345922325311965),
#  ('desir', 0.19322077740853283),
#  ('hop', 0.1915449467102472),
#  ('ist', 0.19138504997141215),
#  ('target', 0.1906734372420295),
#  ('regardless', 0.19066486878666417),
#  ('ram', 0.19051764458915244),
#  ('class', 0.18962258795075226),
#  ('id', 0.18824331790855442),
#  ('accur', 0.18631271083452383),
#  ('train', 0.18562128766372143),
#  ('rotat', 0.18506713064281827),
#  ('brown', 0.1849411643703088),
#  ('rather', 0.1847637379433339),
#  ('potion', 0.18322633852911857),
#  ('gave', 0.18223403340637642),
#  ('elo', 0.18211947796460676),
#  ('extens', 0.18185694090857374),
#  ('unfair', 0.18106832037305343),
#  ('wrong', 0.1808248569088614),
#  ('drop', 0.18024873663519927),
#  ('kit', 0.17881668357440195),
#  ('lol', 0.17870544030002333),
#  ('vari', 0.17788178708068036),
#  ('piec', 0.17759799002722898),
#  ('tree', 0.17633163403462862),
#  ('noon', 0.17556048820086045),
#  ('broke', 0.17448919526270518),
#  ('fanci', 0.17266715242250436),
#  ('anywher', 0.1716947381444469),
#  ('hadnt', 0.17116669131363943),
#  ('move', 0.17036730105086903),
#  ('boy', 0.16996471462379437),
#  ('conclus', 0.16927858470942309),
#  ('oblivion', 0.16885543435079153),
#  ('clone', 0.16652733179345214),
#  ('companion', 0.1663378343087976),
#  ('gamemod', 0.16579318397424908),
#  ('yeah', 0.16427200966721867),
#  ('gameyou', 0.1642344381677031),
#  ('max', 0.16379292634976642),
#  ('invis', 0.16248764051777892),
#  ('pricey', 0.16090586171718652),
#  ('will', 0.16055551526872577),
#  ('storylin', 0.15946429063056955),
#  ('stuff', 0.15926694579937958),
#  ('portion', 0.15820253516520907),
#  ('map', 0.1579874056601096),
#  ('era', 0.15787278711417616),
#  ('situat', 0.15756444356586652),
#  ('caught', 0.15739816434871973),
#  ('win', 0.15714066871332677),
#  ('eas', 0.1569770434931477),
#  ('imagin', 0.15621399810821057),
#  ('comeback', 0.15542717185544735),
#  ('auction', 0.1552655533397104),
#  ('human', 0.1549416630185902),
#  ('site', 0.15394961830450732),
#  ('tanker', 0.153788382763885),
#  ('theyll', 0.15358901719561496),
#  ('strike', 0.15339375841361835),
#  ('attack', 0.15320758682220534),
#  ('loss', 0.15289614981783003),
#  ('thunder', 0.15216628217538172),
#  ('ofcours', 0.1507146667027773),
#  ('increas', 0.150602223672266),
#  ('stream', 0.15035042756464365),
#  ('wide', 0.14849544453239133),
#  ('mode', 0.1483792910761453),
#  ('bag', 0.1475834526796478),
#  ('late', 0.14753298753140223),
#  ('magicka', 0.1474310999212604),
#  ('success', 0.14652835167077566),
#  ('theyr', 0.14636325979184195),
#  ('gotten', 0.14496190891949035),
#  ('trust', 0.14445511668768524),
#  ('slightest', 0.14050327911939156),
#  ('feedback', 0.13917737790474913),
#  ('besid', 0.13916826467276971),
#  ('research', 0.1390945044951984),
#  ('tcgs', 0.1385171362423937),
#  ('interfac', 0.13835537317690527),
#  ('creativ', 0.1370024645759535),
#  ('gameplay', 0.13689451148213172),
#  ('fast', 0.13572806828489004),
#  ('coop', 0.13458891873149265),
#  ('obtain', 0.1341048494377102),
#  ('defin', 0.13358917806858667),
#  ('graphic', 0.13265206041070826),
#  ('search', 0.1326470392137874),
#  ('contain', 0.13207126334742447),
#  ('send', 0.13140276738230128),
#  ('rts', 0.13073584921094838),
#  ('blitz', 0.1304759599381103),
#  ('reddit', 0.13017354407198523),
#  ('reload', 0.12905909167373064),
#  ('nerf', 0.12708588241269742),
#  ('blood', 0.12584689476930666),
#  ('communiti', 0.125467902593011),
#  ('equival', 0.12493751332956757),
#  ('dri', 0.1236253798868617),
#  ('btw', 0.12272996937385003),
#  ('virtual', 0.1224133945003992),
#  ('tri', 0.12240772420403737),
#  ('reli', 0.12113006808892812),
#  ('ssb', 0.12089563776482887),
#  ('gamepad', 0.12049129049097741),
#  ('eye', 0.11979447631545954),
#  ('smaller', 0.11818955869615239),
#  ('aim', 0.11815756155138919),
#  ('individu', 0.1181461917663368),
#  ('newbi', 0.1168125703776015),
#  ('idk', 0.11611308349164007),
#  ('someon', 0.11609585292496613),
#  ('board', 0.11514551958476305),
#  ('path', 0.11471991301677392),
#  ('various', 0.11281115643469591),
#  ('wing', 0.11198895967138536),
#  ('futur', 0.11172469379439955),
#  ('slight', 0.11033608659220298),
#  ('cornerston', 0.11032705541364635),
#  ('restrict', 0.10941426791235431),
#  ('hunter', 0.10930351888831366),
#  ('date', 0.10822685794750336),
#  ('benefit', 0.10728415590574432),
#  ('xplane', 0.10608505266255905),
#  ('fame', 0.10585112798682711),
#  ('mention', 0.1053049770576634),
#  ('greatest', 0.10510767756668238),
#  ('outfit', 0.10500412991465326),
#  ('fsx', 0.10460280967175375),
#  ('deserv', 0.10443814392172394),
#  ('stat', 0.10418039248956956),
#  ('endgam', 0.10403397730309305),
#  ('basic', 0.10251718582068026),
#  ('child', 0.10238476095230584),
#  ('refresh', 0.10070477446926927),
#  ('cri', 0.10058190323175575),
#  ('thompson', 0.10033026930689519)]

# %%
test_1 = test_X[:1000]

# %%
test_tokens = preprocessing(test_1)

# %%
## 기준점수가 0이 아닌경우가 있다...
## test_set labeling 과정...

def semi_labeling(tkns):
  test_label = []
  for tokens in tkns:
    p = 0
    n = 0
    for t in tokens:
      if t in pos_.keys():
        p+=pos_[t]
      elif t in neg_.keys():
        n+=neg_[t]
      else:
        None
    
    if p+n <= 0:
      test_label.append(0)
    elif p+n > 0:
      test_label.append(1)
  
  return test_label

test_label = semi_labeling(test_tokens)

# %%
## 예측값과 실제값 정확도 측정

def cal_acc(y, pred):
  accuracy = np.mean(np.equal(y,pred))

  return accuracy

acc = cal_acc(test_Y[:1000],test_label)
acc

# %%
## 추가 생성된 사전에서 threshold 이상의 값을 가지는 단어만 본 사전에 업데이트 진행

def update_dict(score_dict, threshold): 

  p_count = 0
  n_count = 0

  for (k,v) in score_dict.items():
    if abs(v) > threshold:
      if (k not in pos_) or (k not in neg_):
        if v < 0:
          pos_[k] = v
          p_count+=1
        else:
          neg_[k] = v
          n_count+=1
      else:
        if (v < 0) and (pos_[k] > v):
          pos_[k] = v
          p_count+=1
        elif (v > 0) and (neg_[k] < v): 
          neg_[k] = v
          n_count+=1
        else:
          None

  print('긍정단어 %d개, 부정단어 %d개 업데이트'%(p_count, n_count))

  return pos_, neg_

# %%
## 뒤에서 부터 1000개 validation data 생성

val_X = preprocessing(test_X[-1000:])
val_y = np.array(test_Y[-1000:])

# %%
p = len(pos_)
n = len(neg_)

v_acc = []
t_acc = []
t_acc.append(acc)

for i in tqdm(range(1,35)):
  test_cnts = test_X[1000*i:1000*(i+1)]
  test_tokens = preprocessing(test_cnts)
  test_corp = corpus(test_tokens)
  test_label = semi_labeling(test_tokens)
  real_label = np.array(test_Y[1000*i:1000*(i+1)])

  score_dict = score_importance(test_corp, test_label)
  normalize_dict = dict_normalize(score_dict)
  pos_, neg_ = update_dict(normalize_dict,0.5)
  
  print("test set 정확도 :",cal_acc(real_label,test_label))
  t_acc.append(cal_acc(real_label,test_label))

  prediction = semi_labeling(val_X)
  print(Counter(prediction))
  acc = cal_acc(val_y,prediction)
  v_acc.append(acc)

  print("#"*40)
  print('사전 업데이트 후 정확도',acc)
  print("#"*40)
# Out:
#   3%|▎         | 1/34 [00:03<01:50,  3.36s/it]
# 긍정단어 7개, 부정단어 4개 업데이트
# test set 정확도 : 0.853
# Counter({1: 723, 0: 277})
# ########################################
# 사전 업데이트 후 정확도 0.825
# ########################################
#   6%|▌         | 2/34 [00:06<01:48,  3.40s/it]
# 긍정단어 4개, 부정단어 3개 업데이트
# test set 정확도 : 0.839
# Counter({1: 699, 0: 301})
# ########################################
# 사전 업데이트 후 정확도 0.811
# ########################################
#   9%|▉         | 3/34 [00:10<01:47,  3.48s/it]
# 긍정단어 6개, 부정단어 3개 업데이트
# test set 정확도 : 0.816
# Counter({1: 682, 0: 318})
# ########################################
# 사전 업데이트 후 정확도 0.798
# ########################################
#  12%|█▏        | 4/34 [00:14<01:45,  3.51s/it]
# 긍정단어 3개, 부정단어 2개 업데이트
# test set 정확도 : 0.802
# Counter({1: 687, 0: 313})
# ########################################
# 사전 업데이트 후 정확도 0.805
# ########################################
#  15%|█▍        | 5/34 [00:17<01:43,  3.55s/it]
# 긍정단어 3개, 부정단어 4개 업데이트
# test set 정확도 : 0.82
# Counter({1: 695, 0: 305})
# ########################################
# 사전 업데이트 후 정확도 0.813
# ########################################
#  18%|█▊        | 6/34 [00:21<01:39,  3.57s/it]
# 긍정단어 3개, 부정단어 1개 업데이트
# test set 정확도 : 0.796
# Counter({1: 704, 0: 296})
# ########################################
# 사전 업데이트 후 정확도 0.816
# ########################################
#  21%|██        | 7/34 [00:24<01:35,  3.55s/it]
# 긍정단어 2개, 부정단어 1개 업데이트
# test set 정확도 : 0.808
# Counter({1: 704, 0: 296})
# ########################################
# 사전 업데이트 후 정확도 0.818
# ########################################
#  24%|██▎       | 8/34 [00:28<01:31,  3.54s/it]
# 긍정단어 1개, 부정단어 2개 업데이트
# test set 정확도 : 0.813
# Counter({1: 702, 0: 298})
# ########################################
# 사전 업데이트 후 정확도 0.818
# ########################################
#  26%|██▋       | 9/34 [00:32<01:30,  3.60s/it]
# 긍정단어 2개, 부정단어 1개 업데이트
# test set 정확도 : 0.826
# Counter({1: 702, 0: 298})
# ########################################
# 사전 업데이트 후 정확도 0.816
# ########################################
#  29%|██▉       | 10/34 [00:35<01:26,  3.59s/it]
# 긍정단어 1개, 부정단어 0개 업데이트
# test set 정확도 : 0.837
# Counter({1: 702, 0: 298})
# ########################################
# 사전 업데이트 후 정확도 0.816
# ########################################
#  32%|███▏      | 11/34 [00:39<01:22,  3.61s/it]
# 긍정단어 2개, 부정단어 1개 업데이트
# test set 정확도 : 0.818
# Counter({1: 705, 0: 295})
# ########################################
# 사전 업데이트 후 정확도 0.819
# ########################################
#  35%|███▌      | 12/34 [00:42<01:18,  3.56s/it]
# 긍정단어 1개, 부정단어 1개 업데이트
# test set 정확도 : 0.846
# Counter({1: 705, 0: 295})
# ########################################
# 사전 업데이트 후 정확도 0.819
# ########################################
#  38%|███▊      | 13/34 [00:46<01:16,  3.63s/it]
# 긍정단어 2개, 부정단어 1개 업데이트
# test set 정확도 : 0.824
# Counter({1: 706, 0: 294})
# ########################################
# 사전 업데이트 후 정확도 0.82
# ########################################
#  41%|████      | 14/34 [00:50<01:11,  3.59s/it]
# 긍정단어 3개, 부정단어 2개 업데이트
# test set 정확도 : 0.827
# Counter({1: 698, 0: 302})
# ########################################
# 사전 업데이트 후 정확도 0.816
# ########################################
#  44%|████▍     | 15/34 [00:53<01:07,  3.56s/it]
# 긍정단어 9개, 부정단어 6개 업데이트
# test set 정확도 : 0.821
# Counter({1: 717, 0: 283})
# ########################################
# 사전 업데이트 후 정확도 0.825
# ########################################
#  47%|████▋     | 16/34 [00:56<01:03,  3.53s/it]
# 긍정단어 4개, 부정단어 4개 업데이트
# test set 정확도 : 0.826
# Counter({1: 719, 0: 281})
# ########################################
# 사전 업데이트 후 정확도 0.825
# ########################################
#  50%|█████     | 17/34 [01:00<01:00,  3.55s/it]
# 긍정단어 4개, 부정단어 2개 업데이트
# test set 정확도 : 0.856
# Counter({1: 704, 0: 296})
# ########################################
# 사전 업데이트 후 정확도 0.816
# ########################################
#  53%|█████▎    | 18/34 [01:04<00:56,  3.53s/it]
# 긍정단어 5개, 부정단어 4개 업데이트
# test set 정확도 : 0.84
# Counter({1: 707, 0: 293})
# ########################################
# 사전 업데이트 후 정확도 0.821
# ########################################
#  56%|█████▌    | 19/34 [01:07<00:53,  3.57s/it]
# 긍정단어 3개, 부정단어 3개 업데이트
# test set 정확도 : 0.818
# Counter({1: 710, 0: 290})
# ########################################
# 사전 업데이트 후 정확도 0.82
# ########################################
#  59%|█████▉    | 20/34 [01:11<00:49,  3.56s/it]
# 긍정단어 4개, 부정단어 3개 업데이트
# test set 정확도 : 0.832
# Counter({1: 714, 0: 286})
# ########################################
# 사전 업데이트 후 정확도 0.826
# ########################################
#  62%|██████▏   | 21/34 [01:14<00:46,  3.59s/it]
# 긍정단어 6개, 부정단어 2개 업데이트
# test set 정확도 : 0.823
# Counter({1: 713, 0: 287})
# ########################################
# 사전 업데이트 후 정확도 0.823
# ########################################
#  65%|██████▍   | 22/34 [01:18<00:42,  3.57s/it]
# 긍정단어 1개, 부정단어 1개 업데이트
# test set 정확도 : 0.808
# Counter({1: 701, 0: 299})
# ########################################
# 사전 업데이트 후 정확도 0.817
# ########################################
#  68%|██████▊   | 23/34 [01:19<00:30,  2.80s/it]
# 긍정단어 4개, 부정단어 1개 업데이트
# test set 정확도 : 0.8415637860082305
# Counter({1: 683, 0: 317})
# ########################################
# 사전 업데이트 후 정확도 0.803
# ########################################
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-6b8b8db8a45d> in <module>()
#      13   real_label = np.array(tlabel[1000*i:1000*(i+1)])
#      14
# ---> 15   score_dict = score_importance(test_corp, test_label)
#      16   normalize_dict = dict_normalize(score_dict)
#      17   pos_, neg_ = update_dict(normalize_dict,0.5)
#
# <ipython-input-28-30f619334ce1> in score_importance(corpus, label)
#       9   from sklearn import svm
#      10   vector = TfidfVectorizer()
# ---> 11   tfidf_matrix = vector.fit_transform(corpus).toarray()
#      12
#      13   svm = svm.SVC(C=1.0, kernel='linear',degree = 1, probability=True)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1857         """
#    1858         self._check_params()
# -> 1859         X = super().fit_transform(raw_documents)
#    1860         self._tfidf.fit(X)
#    1861         # X is already a transformed view of raw_documents so
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1218
#    1219         vocabulary, X = self._count_vocab(raw_documents,
# -> 1220                                           self.fixed_vocabulary_)
#    1221
#    1222         if self.binary:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1148             vocabulary = dict(vocabulary)
#    1149             if not vocabulary:
# -> 1150                 raise ValueError("empty vocabulary; perhaps the documents only"
#    1151                                  " contain stop words")
#    1152
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
plt.plot(v_acc)
plt.plot(t_acc, linestyle='--')
plt.legend(['v_acc', 't_acc'])
plt.ylim(0.690, 0.875)

plt.show()

# %%
t_acc

# %%
v_acc
